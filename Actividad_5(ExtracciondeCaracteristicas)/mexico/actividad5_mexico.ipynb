# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from funpymodeling.exploratory import freq_tbl

# %%
#Cargar archivo csv sin indice 

mexico = pd.read_csv('Datos_limpios_mexico.csv')

# %%
#Verificamos informacion del dataframe
mexico.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26582 entries, 0 to 26581
# Data columns (total 51 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   Unnamed: 0                                    26582 non-null  int64
#  1   listing_url                                   26582 non-null  object
#  2   host_since                                    26582 non-null  object
#  3   host_response_time                            26582 non-null  object
#  4   host_response_rate                            26582 non-null  object
#  5   host_acceptance_rate                          26582 non-null  object
#  6   host_is_superhost                             26582 non-null  object
#  7   host_verifications                            26582 non-null  object
#  8   neighbourhood_cleansed                        26582 non-null  object
# ...

# %%
#Mostramos los primeros 5 registros 
mexico.head()
# Out:
#    Unnamed: 0                          listing_url  host_since  \
# 0           0   https://www.airbnb.com/rooms/35797  2010-06-28
# 1           1   https://www.airbnb.com/rooms/44616  2010-08-09
# 2           2   https://www.airbnb.com/rooms/67703  2011-01-04
# 3           3   https://www.airbnb.com/rooms/70644  2010-08-24
# 4           4  https://www.airbnb.com/rooms/107078  2011-04-27
#
#    host_response_time host_response_rate host_acceptance_rate  \
# 0  a few days or more                 0%                  92%
# 1      within an hour               100%                  93%
# 2      within an hour                71%                  57%
# 3  within a few hours               100%                 100%
# 4      within an hour               100%                 100%
#
#   host_is_superhost                host_verifications neighbourhood_cleansed  \
# 0                 f  ['email', 'phone', 'work_email']  Cuajimalpa de Morelos
# ...

# %%
#Eliminamos columnas innecesarias 
mexico = mexico.drop(['Unnamed: 0'], axis=1)

# %%
#Verificamos las columnas 
mexico.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26582 entries, 0 to 26581
# Data columns (total 50 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   listing_url                                   26582 non-null  object
#  1   host_since                                    26582 non-null  object
#  2   host_response_time                            26582 non-null  object
#  3   host_response_rate                            26582 non-null  object
#  4   host_acceptance_rate                          26582 non-null  object
#  5   host_is_superhost                             26582 non-null  object
#  6   host_verifications                            26582 non-null  object
#  7   neighbourhood_cleansed                        26582 non-null  object
#  8   property_type                                 26582 non-null  object
# ...

# %%
#Obtenemos un análisis univariado de las variables categoricas
freq_tbl(mexico)
# Out:
#                                             listing_url  frequency  \
# 0                    https://www.airbnb.com/rooms/35797          1
# 1       https://www.airbnb.com/rooms/897363738676670896          1
# 2       https://www.airbnb.com/rooms/897393613987324079          1
# 3       https://www.airbnb.com/rooms/894989092198576906          1
# 4       https://www.airbnb.com/rooms/894977949284306624          1
# ...                                                 ...        ...
# 26577             https://www.airbnb.com/rooms/47124933          1
# 26578             https://www.airbnb.com/rooms/47123755          1
# 26579             https://www.airbnb.com/rooms/47036712          1
# 26580             https://www.airbnb.com/rooms/47035738          1
# 26581  https://www.airbnb.com/rooms/1252229157495978163          1
#
#        percentage  cumulative_perc
# 0        0.000038         0.000038
# 1        0.000038         0.000075
# 2        0.000038         0.000113
# ...

# %%
#Obtenemos un analisis univariado de una variable categorica en especifico
tabla1 = freq_tbl(mexico['listing_url'])
tabla1
# Out:
#                                             listing_url  frequency  \
# 0                    https://www.airbnb.com/rooms/35797          1
# 1       https://www.airbnb.com/rooms/897363738676670896          1
# 2       https://www.airbnb.com/rooms/897393613987324079          1
# 3       https://www.airbnb.com/rooms/894989092198576906          1
# 4       https://www.airbnb.com/rooms/894977949284306624          1
# ...                                                 ...        ...
# 26577             https://www.airbnb.com/rooms/47124933          1
# 26578             https://www.airbnb.com/rooms/47123755          1
# 26579             https://www.airbnb.com/rooms/47036712          1
# 26580             https://www.airbnb.com/rooms/47035738          1
# 26581  https://www.airbnb.com/rooms/1252229157495978163          1
#
#        percentage  cumulative_perc
# 0        0.000038         0.000038
# 1        0.000038         0.000075
# 2        0.000038         0.000113
# ...

# %%
#Realizamos grafico de dispersion del dataframe filtrado
tabla1.plot("frequency", "cumulative_perc", kind="scatter")
# Out:
# <Axes: xlabel='frequency', ylabel='cumulative_perc'>

# %%
tabla2 = freq_tbl(Londres['host_is_superhost'])
tabla2
# Out:
#   host_is_superhost  frequency  percentage  cumulative_perc
# 0                 f      15346    0.577308         0.577308
# 1                 t      11236    0.422692         1.000000

# %%
tabla3 = tabla2.drop(['percentage', 'cumulative_perc'], axis=1)
tabla3
# Out:
#   host_is_superhost  frequency
# 0                 f      15346
# 1                 t      11236

# %%
filtro = tabla2[(tabla2["frequency"] > 1000)]
filtro
# Out:
#   host_is_superhost  frequency  percentage  cumulative_perc
# 0                 f      15346    0.577308         0.577308
# 1                 t      11236    0.422692         1.000000

# %%
#Ajusto el indice de mi DataFrame
filtro_index = filtro.set_index('host_is_superhost')
filtro_index
# Out:
#                    frequency  percentage  cumulative_perc
# host_is_superhost
# f                      15346    0.577308         0.577308
# t                      11236    0.422692         1.000000

# %%
#Realizamos grafico de barras del Dataframe filtrado
filtro_index.plot(kind = 'bar', width=0.8, figsize=(10,4), color = "red")
plt.title('Super_host')
plt.xlabel('Tipo de super_host')
plt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')

# %%
tabla4 = freq_tbl(mexico['host_since'])
tabla4
# Out:
#       host_since  frequency  percentage  cumulative_perc
# 0     2023-01-30        267    0.010044         0.010044
# 1     2013-12-22        216    0.008126         0.018170
# 2     2020-02-02        177    0.006659         0.024829
# 3     2023-09-28        174    0.006546         0.031375
# 4     2016-04-27        156    0.005869         0.037243
# ...          ...        ...         ...              ...
# 4045  2015-05-24          1    0.000038         0.999850
# 4046  2019-01-13          1    0.000038         0.999887
# 4047  2022-03-31          1    0.000038         0.999925
# 4048  2014-06-05          1    0.000038         0.999962
# 4049  2011-08-25          1    0.000038         1.000000
#
# [4050 rows x 4 columns]

# %%
#Realizamos grafico de dispersion del dataframe filtrado
tabla4.plot("frequency", "cumulative_perc", kind="scatter")
# Out:
# <Axes: xlabel='frequency', ylabel='cumulative_perc'>

# %%
#Obtengo un análisis univariado de una variable categórica en específico  
tabla5 = freq_tbl(mexico['host_response_time'])
tabla5
# Out:
#    host_response_time  frequency  percentage  cumulative_perc
# 0      within an hour      18792    0.706945         0.706945
# 1  a few days or more       4730    0.177940         0.884885
# 2  within a few hours       1957    0.073621         0.958506
# 3        within a day       1103    0.041494         1.000000

# %%
#Elimino las columnas "procentage" y "cumulative_perc" para trabajar con las fecuencias
tabla6 = tabla5.drop(['percentage', 'cumulative_perc'], axis=1)
tabla6
# Out:
#    host_response_time  frequency
# 0      within an hour      18792
# 1  a few days or more       4730
# 2  within a few hours       1957
# 3        within a day       1103

# %%
#Obtengo un filtro de los valores más relevantes de las variables categóricas seleccionado
filtro2 = tabla6[tabla6['frequency']!=592]
filtro2
# Out:
#    host_response_time  frequency
# 0      within an hour      18792
# 1  a few days or more       4730
# 2  within a few hours       1957
# 3        within a day       1103

# %%
#Ajusto el indice de mi DataFrame
filtro_index2 = filtro2.set_index('host_response_time')
filtro_index2
# Out:
#                     frequency
# host_response_time
# within an hour          18792
# a few days or more       4730
# within a few hours       1957
# within a day             1103

# %%
#Realizamos grafico de área del dataframe filtrado
filtro_index2.plot(kind='area', figsize=(10,4),alpha = 0.5)
# Out:
# <Axes: xlabel='host_response_time'>

# %%
tabla7 = freq_tbl(mexico['neighbourhood_cleansed'])
tabla7
# Out:
#     neighbourhood_cleansed  frequency  percentage  cumulative_perc
# 0               Cuauhtémoc      12231    0.460123         0.460123
# 1           Miguel Hidalgo       4533    0.170529         0.630652
# 2            Benito Juárez       3152    0.118576         0.749229
# 3                 Coyoacán       1719    0.064668         0.813897
# 4           Álvaro Obregón       1075    0.040441         0.854338
# 5                  Tlalpan        812    0.030547         0.884885
# 6      Venustiano Carranza        734    0.027613         0.912497
# 7        Gustavo A. Madero        506    0.019035         0.931533
# 8    Cuajimalpa de Morelos        442    0.016628         0.948160
# 9                Iztacalco        399    0.015010         0.963171
# 10            Azcapotzalco        349    0.013129         0.976300
# 11              Iztapalapa        266    0.010007         0.986307
# 12  La Magdalena Contreras        143    0.005380         0.991686
# ...

# %%
#Realizamos grafico hexadecimal del dataframe filtrado, alternativo a scatter plot
tabla7.plot.hexbin("frequency", "cumulative_perc", figsize=(10,5))
# Out:
# <Axes: xlabel='frequency', ylabel='cumulative_perc'>

# %%
tabla8 = freq_tbl(mexico['property_type'])
tabla8
# Out:
#                   property_type  frequency  percentage  cumulative_perc
# 0            Entire rental unit       9971    0.375103         0.375103
# 1                  Entire condo       3423    0.128771         0.503875
# 2   Private room in rental unit       3034    0.114137         0.618012
# 3          Private room in home       2266    0.085246         0.703258
# 4                   Entire loft       1515    0.056993         0.760251
# ..                          ...        ...         ...              ...
# 87        Private room in floor          1    0.000038         0.999850
# 88                 Earthen home          1    0.000038         0.999887
# 89                Entire in-law          1    0.000038         0.999925
# 90          Shared room in dorm          1    0.000038         0.999962
# 91                        Tower          1    0.000038         1.000000
#
# [92 rows x 4 columns]

# %%
filtro3 = tabla8[(tabla8["frequency"] > 100)]
filtro3
# Out:
#                          property_type  frequency  percentage  cumulative_perc
# 0                   Entire rental unit       9971    0.375103         0.375103
# 1                         Entire condo       3423    0.128771         0.503875
# 2          Private room in rental unit       3034    0.114137         0.618012
# 3                 Private room in home       2266    0.085246         0.703258
# 4                          Entire loft       1515    0.056993         0.760251
# 5                Private room in condo        846    0.031826         0.792077
# 6            Entire serviced apartment        846    0.031826         0.823903
# 7                          Entire home        817    0.030735         0.854638
# 8                        Room in hotel        504    0.018960         0.873599
# 9           Private room in guesthouse        381    0.014333         0.887932
# 10  Private room in serviced apartment        284    0.010684         0.898616
# ...

# %%
#Ajusto el indice de mi DataFrame
filtro_index3 = filtro3.set_index('property_type')
filtro_index3
# Out:
#                                     frequency  percentage  cumulative_perc
# property_type
# Entire rental unit                       9971    0.375103         0.375103
# Entire condo                             3423    0.128771         0.503875
# Private room in rental unit              3034    0.114137         0.618012
# Private room in home                     2266    0.085246         0.703258
# Entire loft                              1515    0.056993         0.760251
# Private room in condo                     846    0.031826         0.792077
# Entire serviced apartment                 846    0.031826         0.823903
# Entire home                               817    0.030735         0.854638
# Room in hotel                             504    0.018960         0.873599
# Private room in guesthouse                381    0.014333         0.887932
# Private room in serviced apartment        284    0.010684         0.898616
# ...

# %%
#Realizamos grafico de pastel de dataframe filtrado 
filtro_index3["frequency"].plot(kind="pie", figsize=(10,5), shadow=True, autopct="%0.1f %%")
plt.title('property_type')
plt.xlabel('porcentaje')
plt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')

# %%
#Obtengo un análisis univariado de una variable categórica en específico  
tabla9 = freq_tbl(mexico['room_type'])
tabla9
# Out:
#          room_type  frequency  percentage  cumulative_perc
# 0  Entire home/apt      17363    0.653186         0.653186
# 1     Private room       8693    0.327026         0.980212
# 2      Shared room        401    0.015085         0.995298
# 3       Hotel room        125    0.004702         1.000000

# %%
#Elimino las columnas "procentage" y "cumulative_perc" para trabajar con las fecuencias
tabla10 = tabla9.drop(['percentage', 'cumulative_perc'], axis=1)
tabla10
# Out:
#          room_type  frequency
# 0  Entire home/apt      17363
# 1     Private room       8693
# 2      Shared room        401
# 3       Hotel room        125

# %%
#Obtengo un filtro de los valores más relevantes de las variables categóricas seleccionado
filtro4 = tabla9[tabla9['frequency'] > 30]
filtro4
# Out:
#          room_type  frequency  percentage  cumulative_perc
# 0  Entire home/apt      17363    0.653186         0.653186
# 1     Private room       8693    0.327026         0.980212
# 2      Shared room        401    0.015085         0.995298
# 3       Hotel room        125    0.004702         1.000000

# %%
#Ajusto el indice de mi DataFrame
filtro_index4 = filtro4.set_index('room_type')
filtro_index4
# Out:
#                  frequency  percentage  cumulative_perc
# room_type
# Entire home/apt      17363    0.653186         0.653186
# Private room          8693    0.327026         0.980212
# Shared room            401    0.015085         0.995298
# Hotel room             125    0.004702         1.000000

# %%
#Realizamos grafico de área del dataframe filtrado
filtro_index4.plot(kind='area', figsize=(10,4), alpha = 0.5)
# Out:
# <Axes: xlabel='room_type'>

# %%
tabla11 = freq_tbl(mexico['amenities'])
tabla11
# Out:
#                                                amenities  frequency  \
# 0      ["Iron", "Elevator", "High chair", "Wifi", "Re...         71
# 1      ["Iron", "High chair", "Wifi", "Refrigerator",...         41
# 2                                                     []         40
# 3      ["Iron", "Wifi", "Heating", "Self check-in", "...         29
# 4      ["Iron", "Elevator", "High chair", "Wifi", "Re...         25
# ...                                                  ...        ...
# 24693  ["Host greets you", "Kitchen", "Refrigerator",...          1
# 24694  ["Iron", "Washer", "Private patio or balcony",...          1
# 24695  ["Iron", "Private patio or balcony", "Heating"...          1
# 24696  ["Shared patio or balcony", "Wifi", "Freezer",...          1
# 24697  ["Free parking on premises", "Washer", "TV", "...          1
#
#        percentage  cumulative_perc
# 0        0.002671         0.002671
# 1        0.001542         0.004213
# 2        0.001505         0.005718
# ...

# %%
#Realizamos grafico de dispersion del dataframe filtrado
tabla11.plot("frequency", "cumulative_perc", kind="scatter")
# Out:
# <Axes: xlabel='frequency', ylabel='cumulative_perc'>

# %%
tabla12 = freq_tbl(mexico['has_availability'])
tabla12
# Out:
#   has_availability  frequency  percentage  cumulative_perc
# 0                t      26541    0.998458         0.998458
# 1                f         41    0.001542         1.000000

# %%
#Elimino las columnas "procentage" y "cumulative_perc" para trabajar con las fecuencias
tabla13 = tabla12.drop(['percentage', 'cumulative_perc'], axis=1)
tabla13
# Out:
#   has_availability  frequency
# 0                t      26541
# 1                f         41

# %%
#Obtengo un filtro de los valores más relevantes de las variables categóricas seleccionado
filtro5 = tabla12[tabla12['frequency'] > 1]
filtro5
# Out:
#   has_availability  frequency  percentage  cumulative_perc
# 0                t      26541    0.998458         0.998458
# 1                f         41    0.001542         1.000000

# %%
#Ajusto el indice de mi DataFrame
filtro_index5 = filtro5.set_index('has_availability')
filtro_index5
# Out:
#                   frequency  percentage  cumulative_perc
# has_availability
# t                     26541    0.998458         0.998458
# f                        41    0.001542         1.000000

# %%
#Realizamos grafico de barras del Dataframe filtrado
filtro_index5.plot(kind = 'bar', width=0.8, figsize=(10,4), color = "red")
plt.title('has availability')
plt.xlabel('Disponibilidad')
plt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')

# %%
tabla14 = freq_tbl(mexico['first_review'])
tabla14
# Out:
#      first_review  frequency  percentage  cumulative_perc
# 0      09/11/2011       3656    0.137537         0.137537
# 1      2023-08-27        105    0.003950         0.141487
# 2      2022-10-31        103    0.003875         0.145362
# 3      2023-10-29         82    0.003085         0.148446
# 4      2023-10-30         82    0.003085         0.151531
# ...           ...        ...         ...              ...
# 3321   2016-04-06          1    0.000038         0.999850
# 3322   2020-07-14          1    0.000038         0.999887
# 3323   2016-11-12          1    0.000038         0.999925
# 3324   2021-01-11          1    0.000038         0.999962
# 3325   2018-12-18          1    0.000038         1.000000
#
# [3326 rows x 4 columns]

# %%
#Elimino las coluamnas 'percentage' y 'cumulative_perc' para trabajar con las frecuencias
tabla15 = tabla14.drop(['percentage', 'cumulative_perc'], axis=1)
tabla15
# Out:
#      first_review  frequency
# 0      09/11/2011       3656
# 1      2023-08-27        105
# 2      2022-10-31        103
# 3      2023-10-29         82
# 4      2023-10-30         82
# ...           ...        ...
# 3321   2016-04-06          1
# 3322   2020-07-14          1
# 3323   2016-11-12          1
# 3324   2021-01-11          1
# 3325   2018-12-18          1
#
# [3326 rows x 2 columns]

# %%
#Obtengo un filtro de los valores más relevantes de las variables categorica seleccionada 
filtro6 = tabla14[tabla14['frequency'] > 70]
filtro6
# Out:
#   first_review  frequency  percentage  cumulative_perc
# 0   09/11/2011       3656    0.137537         0.137537
# 1   2023-08-27        105    0.003950         0.141487
# 2   2022-10-31        103    0.003875         0.145362
# 3   2023-10-29         82    0.003085         0.148446
# 4   2023-10-30         82    0.003085         0.151531
# 5   2024-06-30         78    0.002934         0.154465
# 6   2024-09-16         73    0.002746         0.157212

# %%
filtro_index6 = filtro6.set_index('first_review')
filtro_index6
# Out:
#               frequency  percentage  cumulative_perc
# first_review
# 09/11/2011         3656    0.137537         0.137537
# 2023-08-27          105    0.003950         0.141487
# 2022-10-31          103    0.003875         0.145362
# 2023-10-29           82    0.003085         0.148446
# 2023-10-30           82    0.003085         0.151531
# 2024-06-30           78    0.002934         0.154465
# 2024-09-16           73    0.002746         0.157212

# %%
filtro_index6.plot(kind='bar', width=0.8, figsize=(10,4), color='red')
plt.title('Primeras vistas')
plt.xlabel('Fechas')
plt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')

# %%
tabla16 = freq_tbl(mexico['instant_bookable'])
tabla16
# Out:
#   instant_bookable  frequency  percentage  cumulative_perc
# 0                f      16080    0.604921         0.604921
# 1                t      10502    0.395079         1.000000

# %%
#Elimino las coluamnas 'percentage' y 'cumulative_perc' para trabajar con las frecuencias
tabla17 = tabla16.drop(['percentage', 'cumulative_perc'], axis=1)
tabla17
# Out:
#   instant_bookable  frequency
# 0                f      16080
# 1                t      10502

# %%
#Obtengo un filtro de los valores más relevantes de las variables categorica seleccionada 
filtro7 = tabla16[tabla16['frequency'] > 1000]
filtro7
# Out:
#   instant_bookable  frequency  percentage  cumulative_perc
# 0                f      16080    0.604921         0.604921
# 1                t      10502    0.395079         1.000000

# %%
filtro_index7 = filtro7.set_index('instant_bookable')
filtro_index7
# Out:
#                   frequency  percentage  cumulative_perc
# instant_bookable
# f                     16080    0.604921         0.604921
# t                     10502    0.395079         1.000000

# %%
#Realizamos grafico de pastel de dataframe filtrado 
filtro_index7["frequency"].plot(kind="pie", figsize=(10,5), shadow=True, autopct="%0.1f %%")
plt.title('instant_bookable')
plt.xlabel('porcentaje')
plt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')

# %%
tabla18 = freq_tbl(mexico['host_verifications'])
tabla18
# Out:
#                  host_verifications  frequency  percentage  cumulative_perc
# 0                ['email', 'phone']      20504    0.771349         0.771349
# 1  ['email', 'phone', 'work_email']       3381    0.127191         0.898540
# 2                         ['phone']       2527    0.095064         0.993605
# 3           ['phone', 'work_email']        105    0.003950         0.997555
# 4                         ['email']         33    0.001241         0.998796
# 5                                []         30    0.001129         0.999925
# 6           ['email', 'work_email']          1    0.000038         0.999962
# 7                    ['work_email']          1    0.000038         1.000000

# %%
#Elimino las columnas "procentage" y "cumulative_perc" para trabajar con las fecuencias
tabla19 = tabla18.drop(['percentage', 'cumulative_perc'], axis=1)
tabla19
# Out:
#                  host_verifications  frequency
# 0                ['email', 'phone']      20504
# 1  ['email', 'phone', 'work_email']       3381
# 2                         ['phone']       2527
# 3           ['phone', 'work_email']        105
# 4                         ['email']         33
# 5                                []         30
# 6           ['email', 'work_email']          1
# 7                    ['work_email']          1

# %%
#Obtengo un análisis univariado de una variable categórica en específico  
tabla20 = freq_tbl(mexico['last_review'])
tabla20
# Out:
#      last_review  frequency  percentage  cumulative_perc
# 0     26/03/2023       3656    0.137537         0.137537
# 1     2024-09-22       1081    0.040667         0.178203
# 2     2024-09-16       1068    0.040178         0.218381
# 3     2024-09-23        898    0.033782         0.252163
# 4     2024-09-17        711    0.026747         0.278911
# ...          ...        ...         ...              ...
# 1630  2019-04-24          1    0.000038         0.999850
# 1631  2021-08-09          1    0.000038         0.999887
# 1632  2019-10-02          1    0.000038         0.999925
# 1633  2018-07-15          1    0.000038         0.999962
# 1634  2023-11-14          1    0.000038         1.000000
#
# [1635 rows x 4 columns]

# %%
#Elimino las columnas "procentage" y "cumulative_perc" para trabajar con las fecuencias
tabla21 = tabla20.drop(['percentage', 'cumulative_perc'], axis=1)
tabla21
# Out:
#      last_review  frequency
# 0     26/03/2023       3656
# 1     2024-09-22       1081
# 2     2024-09-16       1068
# 3     2024-09-23        898
# 4     2024-09-17        711
# ...          ...        ...
# 1630  2019-04-24          1
# 1631  2021-08-09          1
# 1632  2019-10-02          1
# 1633  2018-07-15          1
# 1634  2023-11-14          1
#
# [1635 rows x 2 columns]

# %%
#Obtengo un filtro de los valores más relevantes de las variables categóricas seleccionado
filtro8 = tabla20[tabla20['frequency'] > 100]
filtro8
# Out:
#    last_review  frequency  percentage  cumulative_perc
# 0   26/03/2023       3656    0.137537         0.137537
# 1   2024-09-22       1081    0.040667         0.178203
# 2   2024-09-16       1068    0.040178         0.218381
# 3   2024-09-23        898    0.033782         0.252163
# 4   2024-09-17        711    0.026747         0.278911
# 5   2024-09-08        680    0.025581         0.304492
# 6   2024-09-01        537    0.020202         0.324693
# 7   2024-09-21        513    0.019299         0.343992
# 8   2024-09-09        422    0.015875         0.359868
# 9   2024-09-02        387    0.014559         0.374426
# 10  2024-09-18        385    0.014483         0.388910
# 11  2024-09-10        380    0.014295         0.403205
# 12  2024-09-15        379    0.014258         0.417463
# 13  2024-09-20        357    0.013430         0.430893
# 14  2024-08-25        347    0.013054         0.443947
# 15  2024-09-07        339    0.012753         0.456700
# ...

# %%
#Ajusto el indice de mi DataFrame
filtro_index8 = filtro8.set_index('last_review')
filtro_index8
# Out:
#              frequency  percentage  cumulative_perc
# last_review
# 26/03/2023        3656    0.137537         0.137537
# 2024-09-22        1081    0.040667         0.178203
# 2024-09-16        1068    0.040178         0.218381
# 2024-09-23         898    0.033782         0.252163
# 2024-09-17         711    0.026747         0.278911
# 2024-09-08         680    0.025581         0.304492
# 2024-09-01         537    0.020202         0.324693
# 2024-09-21         513    0.019299         0.343992
# 2024-09-09         422    0.015875         0.359868
# 2024-09-02         387    0.014559         0.374426
# 2024-09-18         385    0.014483         0.388910
# 2024-09-10         380    0.014295         0.403205
# 2024-09-15         379    0.014258         0.417463
# 2024-09-20         357    0.013430         0.430893
# 2024-08-25         347    0.013054         0.443947
# 2024-09-07         339    0.012753         0.456700
# 2024-09-19         311    0.011700         0.468400
# ...

# %%
#Realizamos grafico de barras del Dataframe filtrado
filtro_index8.plot(kind = 'bar', width=0.8, figsize=(10,4), color = "red")
plt.title('última revsión')
plt.xlabel('Fecha')
plt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')

# %%
mexico['availability_30'] = mexico['availability_30'].astype('category')
tabla22 = freq_tbl(mexico['availability_30'])
tabla22
# Out:
#    availability_30  frequency  percentage  cumulative_perc
# 0                0       6274    0.236024         0.236024
# 1               30       2538    0.095478         0.331503
# 2               29       1495    0.056241         0.387744
# 3               28        980    0.036867         0.424611
# 4               24        909    0.034196         0.458807
# 5               27        899    0.033820         0.492627
# 6               25        813    0.030585         0.523211
# 7               26        809    0.030434         0.553645
# 8               23        782    0.029418         0.583064
# 9               22        644    0.024227         0.607291
# 10              21        629    0.023663         0.630953
# 11              19        593    0.022308         0.653262
# 12              17        588    0.022120         0.675382
# 13              20        586    0.022045         0.697427
# 14              13        564    0.021217         0.718644
# ...

# %%
#Realizamos grafico hexadecimal del dataframe filtrado, alternativo a scatter plot
tabla22.plot.hexbin("frequency", "cumulative_perc", figsize=(10,5))
# Out:
# <Axes: xlabel='frequency', ylabel='cumulative_perc'>

# %%
mexico['latitude'] = mexico['latitude'].astype('category')
tabla23 = freq_tbl(mexico['latitude'])
tabla23
# Out:
#         latitude  frequency  percentage  cumulative_perc
# 0      19.400000       1780    0.066963         0.066963
# 1      19.432848         84    0.003160         0.070123
# 2      19.363644         52    0.001956         0.072079
# 3      19.407353         43    0.001618         0.073696
# 4      19.446401         34    0.001279         0.074976
# ...          ...        ...         ...              ...
# 15822  19.404840          1    0.000038         0.999850
# 15823  19.404850          1    0.000038         0.999887
# 15824  19.404860          1    0.000038         0.999925
# 15825  19.404866          1    0.000038         0.999962
# 15826  19.493974          1    0.000038         1.000000
#
# [15827 rows x 4 columns]

# %%
#Elimino las columnas "procentage" y "cumulative_perc" para trabajar con las fecuencias
tabla24 = tabla23.drop(['percentage', 'cumulative_perc'], axis=1)
tabla24
# Out:
#         latitude  frequency
# 0      19.400000       1780
# 1      19.432848         84
# 2      19.363644         52
# 3      19.407353         43
# 4      19.446401         34
# ...          ...        ...
# 15822  19.404840          1
# 15823  19.404850          1
# 15824  19.404860          1
# 15825  19.404866          1
# 15826  19.493974          1
#
# [15827 rows x 2 columns]

# %%
#Obtengo un filtro de los valores más relevantes de las variables categóricas seleccionado
filtro9 = tabla23[tabla23['frequency'] > 10]
filtro9
# Out:
#      latitude  frequency  percentage  cumulative_perc
# 0   19.400000       1780    0.066963         0.066963
# 1   19.432848         84    0.003160         0.070123
# 2   19.363644         52    0.001956         0.072079
# 3   19.407353         43    0.001618         0.073696
# 4   19.446401         34    0.001279         0.074976
# 5   19.427410         29    0.001091         0.076067
# 6   19.403913         26    0.000978         0.077045
# 7   19.409977         24    0.000903         0.077947
# 8   19.409999         23    0.000865         0.078813
# 9   19.434976         22    0.000828         0.079640
# 10  19.435206         22    0.000828         0.080468
# 11  19.453229         22    0.000828         0.081296
# 12  19.421227         21    0.000790         0.082086
# 13  19.434763         20    0.000752         0.082838
# 14  19.421939         19    0.000715         0.083553
# 15  19.362510         19    0.000715         0.084268
# ...

# %%
#Ajusto el indice de mi DataFrame
filtro_index9 = filtro9.set_index('latitude')
filtro_index9
# Out:
#            frequency  percentage  cumulative_perc
# latitude
# 19.400000       1780    0.066963         0.066963
# 19.432848         84    0.003160         0.070123
# 19.363644         52    0.001956         0.072079
# 19.407353         43    0.001618         0.073696
# 19.446401         34    0.001279         0.074976
# 19.427410         29    0.001091         0.076067
# 19.403913         26    0.000978         0.077045
# 19.409977         24    0.000903         0.077947
# 19.409999         23    0.000865         0.078813
# 19.434976         22    0.000828         0.079640
# 19.435206         22    0.000828         0.080468
# 19.453229         22    0.000828         0.081296
# 19.421227         21    0.000790         0.082086
# 19.434763         20    0.000752         0.082838
# 19.421939         19    0.000715         0.083553
# 19.362510         19    0.000715         0.084268
# 19.407350         18    0.000677         0.084945
# 19.417193         18    0.000677         0.085622
# ...

# %%
#Realizamos grafico de barras del Dataframe filtrado
filtro_index9.plot(kind = 'bar', width=0.8, figsize=(10,4), color = "red")
plt.title('Latitud')
plt.xlabel('latitud')
plt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')

# %%
mexico['longitude'] = mexico['longitude'].astype('category')
#Obtengo un análisis univariado de una variable categórica en específico  
tabla25 = freq_tbl(mexico['longitude'])
tabla25
# Out:
#        longitude  frequency  percentage  cumulative_perc
# 0     -99.200000       2845    0.107027         0.107027
# 1     -99.166157         84    0.003160         0.110187
# 2     -99.150740         52    0.001956         0.112144
# 3     -99.208403         44    0.001655         0.113799
# 4     -99.167820         43    0.001618         0.115416
# ...          ...        ...         ...              ...
# 13624 -99.172746          1    0.000038         0.999850
# 13625 -99.172745          1    0.000038         0.999887
# 13626 -99.172742          1    0.000038         0.999925
# 13627 -99.172740          1    0.000038         0.999962
# 13628 -99.117780          1    0.000038         1.000000
#
# [13629 rows x 4 columns]

# %%
#Elimino las columnas "procentage" y "cumulative_perc" para trabajar con las fecuencias
tabla26 = tabla25.drop(['percentage', 'cumulative_perc'], axis=1)
tabla26
# Out:
#        longitude  frequency
# 0     -99.200000       2845
# 1     -99.166157         84
# 2     -99.150740         52
# 3     -99.208403         44
# 4     -99.167820         43
# ...          ...        ...
# 13624 -99.172746          1
# 13625 -99.172745          1
# 13626 -99.172742          1
# 13627 -99.172740          1
# 13628 -99.117780          1
#
# [13629 rows x 2 columns]

# %%
#Obtengo un filtro de los valores más relevantes de las variables categóricas seleccionado
filtro10 = tabla26[tabla26['frequency'] > 8]
filtro10
# Out:
#      longitude  frequency
# 0   -99.200000       2845
# 1   -99.166157         84
# 2   -99.150740         52
# 3   -99.208403         44
# 4   -99.167820         43
# ..         ...        ...
# 101 -99.199064          9
# 102 -99.170830          9
# 103 -99.165730          9
# 104 -99.146610          9
# 105 -99.145780          9
#
# [106 rows x 2 columns]

# %%
#Ajusto el indice de mi DataFrame
filtro_index10 = filtro10.set_index('longitude')
filtro_index10
# Out:
#             frequency
# longitude
# -99.200000       2845
# -99.166157         84
# -99.150740         52
# -99.208403         44
# -99.167820         43
# ...               ...
# -99.199064          9
# -99.170830          9
# -99.165730          9
# -99.146610          9
# -99.145780          9
#
# [106 rows x 1 columns]

# %%
#Realizamos grafico de barras del Dataframe filtrado
filtro_index10.plot(kind = 'bar', width=0.8, figsize=(10,4), color = "yellow")
plt.title('Longitud')
plt.xlabel('longitudes')
plt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')

# %%
mexico['host_id'] = mexico['host_id'].astype('category')
#Obtengo un análisis univariado de una variable categórica en específico  
tabla27 = freq_tbl(mexico['host_id'])
tabla27
# Out:
#          host_id  frequency  percentage  cumulative_perc
# 0      498701635        258    0.009706         0.009706
# 1       10764020        216    0.008126         0.017832
# 2      333035396        177    0.006659         0.024490
# 3      539407308        170    0.006395         0.030886
# 4       16148871        148    0.005568         0.036453
# ...          ...        ...         ...              ...
# 12087  104949210          1    0.000038         0.999850
# 12088  105108545          1    0.000038         0.999887
# 12089  105110977          1    0.000038         0.999925
# 12090  105130167          1    0.000038         0.999962
# 12091  653503732          1    0.000038         1.000000
#
# [12092 rows x 4 columns]

# %%
#Elimino las columnas "procentage" y "cumulative_perc" para trabajar con las fecuencias
tabla28 = tabla27.drop(['percentage', 'cumulative_perc'], axis=1)
tabla28
# Out:
#          host_id  frequency
# 0      498701635        258
# 1       10764020        216
# 2      333035396        177
# 3      539407308        170
# 4       16148871        148
# ...          ...        ...
# 12087  104949210          1
# 12088  105108545          1
# 12089  105110977          1
# 12090  105130167          1
# 12091  653503732          1
#
# [12092 rows x 2 columns]

# %%
#Obtengo un filtro de los valores más relevantes de las variables categóricas seleccionado
filtro11 = tabla27[tabla27['frequency'] > 20]
filtro11
# Out:
#       host_id  frequency  percentage  cumulative_perc
# 0   498701635        258    0.009706         0.009706
# 1    10764020        216    0.008126         0.017832
# 2   333035396        177    0.006659         0.024490
# 3   539407308        170    0.006395         0.030886
# 4    16148871        148    0.005568         0.036453
# ..        ...        ...         ...              ...
# 85  547380140         22    0.000828         0.153374
# 86   90632904         21    0.000790         0.154164
# 87   49735631         21    0.000790         0.154954
# 88  498096522         21    0.000790         0.155744
# 89  359943588         21    0.000790         0.156534
#
# [90 rows x 4 columns]

# %%
#Ajusto el indice de mi DataFrame
filtro_index11 = filtro11.set_index('host_id')
filtro_index11
# Out:
#            frequency  percentage  cumulative_perc
# host_id
# 498701635        258    0.009706         0.009706
# 10764020         216    0.008126         0.017832
# 333035396        177    0.006659         0.024490
# 539407308        170    0.006395         0.030886
# 16148871         148    0.005568         0.036453
# ...              ...         ...              ...
# 547380140         22    0.000828         0.153374
# 90632904          21    0.000790         0.154164
# 49735631          21    0.000790         0.154954
# 498096522         21    0.000790         0.155744
# 359943588         21    0.000790         0.156534
#
# [90 rows x 3 columns]

# %%
#Realizamos grafico de pastel de dataframe filtrado 
filtro_index11["frequency"].plot(kind="pie", figsize=(10,5), shadow=True, autopct="%0.1f %%")
plt.title('host_id')
plt.xlabel('porcentaje')
plt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')

# %%
mexico['review_scores_rating'] = mexico['review_scores_rating'].astype('category')
#Obtengo un análisis univariado de una variable categórica en específico  
tabla29 = freq_tbl(mexico['review_scores_rating'])
tabla29
# Out:
#    review_scores_rating  frequency  percentage  cumulative_perc
# 0                  5.00       4998    0.188022         0.188022
# 1                  4.91       4117    0.154879         0.342901
# 2                  4.80       2412    0.090738         0.433639
# 3                  4.88        636    0.023926         0.457565
# 4                  4.86        583    0.021932         0.479497
# 5                  4.89        579    0.021782         0.501279
# 6                  4.83        579    0.021782         0.523061
# 7                  4.75        574    0.021594         0.544654
# 8                  4.67        558    0.020992         0.565646
# 9                  4.92        527    0.019825         0.585471
# 10                 4.90        510    0.019186         0.604657
# 11                 4.50        504    0.018960         0.623617
# 12                 4.93        502    0.018885         0.642502
# 13                 4.94        477    0.017944         0.660447
# ...

# %%
#Realizamos grafico de dispersion del dataframe filtrado
tabla29.plot("frequency", "cumulative_perc", kind="scatter")
# Out:
# <Axes: xlabel='frequency', ylabel='cumulative_perc'>

# %%
mexico['minimum_nights'] = mexico['minimum_nights'].astype('category')
#Obtengo un análisis univariado de una variable categórica en específico  
tabla30 = freq_tbl(mexico['minimum_nights'])
tabla30
# Out:
#   minimum_nights  frequency  percentage  cumulative_perc
# 0            1.0      12621    0.474795         0.474795
# 1            2.0       7471    0.281055         0.755850
# 2            3.0       6490    0.244150         1.000000

# %%
#Elimino las columnas "procentage" y "cumulative_perc" para trabajar con las fecuencias
tabla31 = tabla30.drop(['percentage', 'cumulative_perc'], axis=1)
tabla31
# Out:
#   minimum_nights  frequency
# 0            1.0      12621
# 1            2.0       7471
# 2            3.0       6490

# %%
#Obtengo un filtro de los valores más relevantes de las variables categóricas seleccionado
filtro12 = tabla30[tabla30['frequency'] > 8]
filtro12
# Out:
#   minimum_nights  frequency  percentage  cumulative_perc
# 0            1.0      12621    0.474795         0.474795
# 1            2.0       7471    0.281055         0.755850
# 2            3.0       6490    0.244150         1.000000

# %%
#Ajusto el indice de mi DataFrame
filtro_index12 = filtro12.set_index('minimum_nights')
filtro_index12
# Out:
#                 frequency  percentage  cumulative_perc
# minimum_nights
# 1.0                 12621    0.474795         0.474795
# 2.0                  7471    0.281055         0.755850
# 3.0                  6490    0.244150         1.000000

# %%
#Realizamos grafico de pastel del dataframe filtrado
filtro_index12["frequency"].plot(kind='pie', figsize=(10,5), shadow=True, autopct="%0.1f %%")
# Out:
# <Axes: ylabel='frequency'>

# %%
mexico['maximum_nights'] = mexico['maximum_nights'].astype('category')
#Obtengo un análisis univariado de una variable categórica en específico  
tabla32 = freq_tbl(mexico['maximum_nights'])
tabla32
# Out:
#     maximum_nights  frequency  percentage  cumulative_perc
# 0              365      10638    0.400196         0.400196
# 1             1125       7983    0.300316         0.700512
# 2               30       1271    0.047814         0.748326
# 3               90        932    0.035061         0.783387
# 4               60        742    0.027914         0.811301
# ..             ...        ...         ...              ...
# 186            193          1    0.000038         0.999850
# 187            188          1    0.000038         0.999887
# 188            187          1    0.000038         0.999925
# 189            184          1    0.000038         0.999962
# 190           1825          1    0.000038         1.000000
#
# [191 rows x 4 columns]

# %%
#Elimino las columnas "procentage" y "cumulative_perc" para trabajar con las fecuencias
tabla33 = tabla32.drop(['percentage', 'cumulative_perc'], axis=1)
tabla33
# Out:
#     maximum_nights  frequency
# 0              365      10638
# 1             1125       7983
# 2               30       1271
# 3               90        932
# 4               60        742
# ..             ...        ...
# 186            193          1
# 187            188          1
# 188            187          1
# 189            184          1
# 190           1825          1
#
# [191 rows x 2 columns]

# %%
#Obtengo un filtro de los valores más relevantes de las variables categóricas seleccionado
filtro13 = tabla32[tabla32['frequency'] > 100]
filtro13
# Out:
#    maximum_nights  frequency  percentage  cumulative_perc
# 0             365      10638    0.400196         0.400196
# 1            1125       7983    0.300316         0.700512
# 2              30       1271    0.047814         0.748326
# 3              90        932    0.035061         0.783387
# 4              60        742    0.027914         0.811301
# 5             730        462    0.017380         0.828681
# 6             180        428    0.016101         0.844782
# 7              15        387    0.014559         0.859341
# 8              28        347    0.013054         0.872395
# 9             120        296    0.011135         0.883530
# 10             31        273    0.010270         0.893800
# 11              7        225    0.008464         0.902265
# 12             20        148    0.005568         0.907832
# 13             45        140    0.005267         0.913099
# 14             10        135    0.005079         0.918178
# ...

# %%
#Ajusto el indice de mi DataFrame
filtro_index13 = filtro13.set_index('maximum_nights')
filtro_index13
# Out:
#                 frequency  percentage  cumulative_perc
# maximum_nights
# 365                 10638    0.400196         0.400196
# 1125                 7983    0.300316         0.700512
# 30                   1271    0.047814         0.748326
# 90                    932    0.035061         0.783387
# 60                    742    0.027914         0.811301
# 730                   462    0.017380         0.828681
# 180                   428    0.016101         0.844782
# 15                    387    0.014559         0.859341
# 28                    347    0.013054         0.872395
# 120                   296    0.011135         0.883530
# 31                    273    0.010270         0.893800
# 7                     225    0.008464         0.902265
# 20                    148    0.005568         0.907832
# 45                    140    0.005267         0.913099
# 10                    135    0.005079         0.918178
# 100                   127    0.004778         0.922955
# ...

# %%
#Realizamos grafico de área del dataframe filtrado
filtro_index13.plot(kind='area', figsize=(10,4), alpha = 0.5)
# Out:
# <Axes: xlabel='maximum_nights'>

# %% [markdown]
# Determinacion de clases para datos agrupados para 17 variables

# %%
#Corroboramos valores nulos 
valores_nulos = mexico.isnull().sum()
valores_nulos
# Out:
# listing_url                                     0
# host_since                                      0
# host_response_time                              0
# host_response_rate                              0
# host_acceptance_rate                            0
# host_is_superhost                               0
# host_verifications                              0
# neighbourhood_cleansed                          0
# property_type                                   0
# room_type                                       0
# bathrooms_text                                  0
# amenities                                       0
# price                                           0
# has_availability                                0
# first_review                                    0
# last_review                                     0
# instant_bookable                                0
# id                                              0
# host_id                                         0
# ...

# %%
mexico['availability_365'].info()
n = 8021
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 26582 entries, 0 to 26581
# Series name: availability_365
# Non-Null Count  Dtype
# --------------  -----
# 26582 non-null  int64
# dtypes: int64(1)
# memory usage: 207.8 KB

# %%
Min = mexico['availability_365'].min()  
Max = mexico['availability_365'].max()  
Limites = [Min,Max]
Limites
# Out:
# [0, 365]

# %%
R = Max - Min
R
# Out:
# 365

# %%
ni = 1+3.32*np.log10(n)
ni
# Out:
# 13.96203867424906

# %%
i = R/ni
i
# Out:
# 26.14231406429128

# %%
# Ver resultado
intervalos = np.linspace(0.0, 365, 14) #Número de clases más uno
intervalos
# Out:
# array([  0.        ,  28.07692308,  56.15384615,  84.23076923,
#        112.30769231, 140.38461538, 168.46153846, 196.53846154,
#        224.61538462, 252.69230769, 280.76923077, 308.84615385,
#        336.92307692, 365.        ])

# %%
categorias = ["Categoría1", "Categoría2", "Categoría3", "Categoría4",
              "Categoría5", "Categoría6", "Categoría7", "Categoría8",
              "Categoría9","Categoría10","Categoría11","Categoría12",
              "Categoria13"]

# %%
mexico["availability_365"] = pd.cut(x = mexico["availability_365"], bins = intervalos, labels = categorias)
mexico["availability_365"]
# Out:
# 0        Categoria13
# 1        Categoría12
# 2        Categoría12
# 3        Categoría10
# 4        Categoría10
#             ...
# 26577    Categoria13
# 26578     Categoría7
# 26579     Categoría7
# 26580     Categoría7
# 26581     Categoría6
# Name: availability_365, Length: 26582, dtype: category
# Categories (13, object): ['Categoría1' < 'Categoría2' < 'Categoría3' < 'Categoría4' ... 'Categoría10' < 'Categoría11' < 'Categoría12' < 'Categoria13']

# %%
#Obtengo un análisis univariado de una variable categórica en específico  
variable_1 = freq_tbl(mexico['availability_365'])
variable_1
# Out:
#    availability_365  frequency  percentage  cumulative_perc
# 0       Categoria13       7137    0.268490         0.294649
# 1       Categoría12       2836    0.106689         0.411733
# 2       Categoría10       2669    0.100406         0.521922
# 3        Categoría3       1597    0.060078         0.587854
# 4        Categoría9       1420    0.053420         0.646478
# 5        Categoría6       1318    0.049582         0.700892
# 6       Categoría11       1276    0.048002         0.753571
# 7        Categoría4       1250    0.047024         0.805177
# 8        Categoría7       1233    0.046385         0.856081
# 9        Categoría2        996    0.037469         0.897201
# 10       Categoría5        903    0.033970         0.934481
# 11       Categoría1        874    0.032879         0.970564
# 12       Categoría8        713    0.026823         1.000000

# %%
#Elimino las columnas "procentage" y "cumulative_perc" para trabajar con las fecuencias
variable_1_2 = variable_1.drop(['percentage', 'cumulative_perc'], axis=1)
variable_1_2
# Out:
#    availability_365  frequency
# 0       Categoria13       7137
# 1       Categoría12       2836
# 2       Categoría10       2669
# 3        Categoría3       1597
# 4        Categoría9       1420
# 5        Categoría6       1318
# 6       Categoría11       1276
# 7        Categoría4       1250
# 8        Categoría7       1233
# 9        Categoría2        996
# 10       Categoría5        903
# 11       Categoría1        874
# 12       Categoría8        713

# %%
filtro_1 = variable_1_2[variable_1_2['frequency'] > 100]
filtro_1
# Out:
#    availability_365  frequency
# 0       Categoria13       7137
# 1       Categoría12       2836
# 2       Categoría10       2669
# 3        Categoría3       1597
# 4        Categoría9       1420
# 5        Categoría6       1318
# 6       Categoría11       1276
# 7        Categoría4       1250
# 8        Categoría7       1233
# 9        Categoría2        996
# 10       Categoría5        903
# 11       Categoría1        874
# 12       Categoría8        713

# %%
#Ajusto el indice de mi DataFrame
filtro_i = filtro_1.set_index("availability_365")
filtro_i
# Out:
#                   frequency
# availability_365
# Categoria13            7137
# Categoría12            2836
# Categoría10            2669
# Categoría3             1597
# Categoría9             1420
# Categoría6             1318
# Categoría11            1276
# Categoría4             1250
# Categoría7             1233
# Categoría2              996
# Categoría5              903
# Categoría1              874
# Categoría8              713

# %%
#Realizamos grafico de barras del Dataframe filtrado
filtro_i.plot(kind = 'bar', width=0.8, figsize=(10,4), color = "red")
plt.title('Disponible 365')
plt.xlabel('Categoria')
plt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')

# %%
mexico['number_of_reviews'].info()
n = 8021
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 26582 entries, 0 to 26581
# Series name: number_of_reviews
# Non-Null Count  Dtype
# --------------  -----
# 26582 non-null  float64
# dtypes: float64(1)
# memory usage: 207.8 KB

# %%
Min = mexico['number_of_reviews'].min()  
Max = mexico['number_of_reviews'].max()  
Limites = [Min,Max]
Limites
# Out:
# [0.0, 135.0]

# %%
R = Max - Min
R
# Out:
# 135.0

# %%
ni = 1+3.32*np.log10(n)
ni
# Out:
# 13.96203867424906

# %%
i = R/ni
i
# Out:
# 9.669075064874857

# %%
# Ver resultado
intervalos = np.linspace(0.0, 42.0, 14) #Número de clases más uno
intervalos
# Out:
# array([ 0.        ,  3.23076923,  6.46153846,  9.69230769, 12.92307692,
#        16.15384615, 19.38461538, 22.61538462, 25.84615385, 29.07692308,
#        32.30769231, 35.53846154, 38.76923077, 42.        ])

# %%
categorias = ["Categoría1", "Categoría2", "Categoría3", "Categoría4",
              "Categoría5", "Categoría6", "Categoría7", "Categoría8",
              "Categoría9","Categoría10","Categoría11","Categoría12",
              "Categoria13"]

# %%
mexico["number_of_reviews"] = pd.cut(x = mexico["number_of_reviews"], bins = intervalos, labels = categorias)
mexico["number_of_reviews"]
# Out:
# 0               NaN
# 1               NaN
# 2               NaN
# 3               NaN
# 4        Categoría4
#             ...
# 26577           NaN
# 26578           NaN
# 26579           NaN
# 26580           NaN
# 26581           NaN
# Name: number_of_reviews, Length: 26582, dtype: category
# Categories (13, object): ['Categoría1' < 'Categoría2' < 'Categoría3' < 'Categoría4' ... 'Categoría10' < 'Categoría11' < 'Categoría12' < 'Categoria13']

# %%
#Obtengo un análisis univariado de una variable categórica en específico  
variable_2 = freq_tbl(mexico['number_of_reviews'])
variable_2
# Out:
#    number_of_reviews  frequency  percentage  cumulative_perc
# 0         Categoría1       3610    0.135806         0.211643
# 1        Categoría12       2793    0.105071         0.375388
# 2         Categoría2       2110    0.079377         0.499091
# 3         Categoría3       1522    0.057257         0.588322
# 4         Categoría5       1244    0.046799         0.661253
# 5         Categoría4       1194    0.044918         0.731254
# 6         Categoría6        830    0.031224         0.779914
# 7         Categoría9        795    0.029907         0.826523
# 8         Categoría7        689    0.025920         0.866917
# 9         Categoría8        668    0.025130         0.906080
# 10       Categoria13        559    0.021029         0.938852
# 11       Categoría10        540    0.020314         0.970511
# 12       Categoría11        503    0.018923         1.000000

# %%
#Elimino las columnas "procentage" y "cumulative_perc" para trabajar con las fecuencias
variable_2_2 = variable_2.drop(['percentage', 'cumulative_perc'], axis=1)
variable_2_2
# Out:
#    number_of_reviews  frequency
# 0         Categoría1       3610
# 1        Categoría12       2793
# 2         Categoría2       2110
# 3         Categoría3       1522
# 4         Categoría5       1244
# 5         Categoría4       1194
# 6         Categoría6        830
# 7         Categoría9        795
# 8         Categoría7        689
# 9         Categoría8        668
# 10       Categoria13        559
# 11       Categoría10        540
# 12       Categoría11        503

# %%
filtro_2 = variable_2_2[variable_2_2['frequency'] > 100]
filtro_2
# Out:
#    number_of_reviews  frequency
# 0         Categoría1       3610
# 1        Categoría12       2793
# 2         Categoría2       2110
# 3         Categoría3       1522
# 4         Categoría5       1244
# 5         Categoría4       1194
# 6         Categoría6        830
# 7         Categoría9        795
# 8         Categoría7        689
# 9         Categoría8        668
# 10       Categoria13        559
# 11       Categoría10        540
# 12       Categoría11        503

# %%
#Ajusto el indice de mi DataFrame
filtro_i2 = filtro_2.set_index("number_of_reviews")
filtro_i2
# Out:
#                    frequency
# number_of_reviews
# Categoría1              3610
# Categoría12             2793
# Categoría2              2110
# Categoría3              1522
# Categoría5              1244
# Categoría4              1194
# Categoría6               830
# Categoría9               795
# Categoría7               689
# Categoría8               668
# Categoria13              559
# Categoría10              540
# Categoría11              503

# %%
#Realizamos grafico de barras del Dataframe filtrado
filtro_i2.plot(kind = 'bar', width=0.8, figsize=(10,4), color = "red")
plt.title('Numero de reseñas')
plt.xlabel('Categoria')
plt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')

# %%
mexico['review_scores_location'].info()
n = 8021
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 26582 entries, 0 to 26581
# Series name: review_scores_location
# Non-Null Count  Dtype
# --------------  -----
# 26582 non-null  float64
# dtypes: float64(1)
# memory usage: 207.8 KB

# %%
Min = mexico['review_scores_location'].min()  
Max = mexico['review_scores_location'].max()  
Limites = [Min,Max]
Limites
# Out:
# [4.5, 5.0]

# %%
R = Max - Min
R
# Out:
# 0.5

# %%
ni = 1+3.32*np.log10(n)
ni
# Out:
# 13.96203867424906

# %%
i = R/ni
i
# Out:
# 0.03581138912916614

# %%
# Ver resultado
intervalos = np.linspace(4.6, 5.0, 14) #Número de clases más uno
intervalos
# Out:
# array([4.6       , 4.63076923, 4.66153846, 4.69230769, 4.72307692,
#        4.75384615, 4.78461538, 4.81538462, 4.84615385, 4.87692308,
#        4.90769231, 4.93846154, 4.96923077, 5.        ])

# %%
categorias = ["Categoría1", "Categoría2", "Categoría3", "Categoría4",
              "Categoría5", "Categoría6", "Categoría7", "Categoría8",
              "Categoría9","Categoría10","Categoría11","Categoría12",
              "Categoria13"]

# %%
mexico["review_scores_location"] = pd.cut(x = mexico["review_scores_location"], bins = intervalos, labels = categorias)
mexico["review_scores_location"]
# Out:
# 0         Categoría7
# 1        Categoria13
# 2        Categoria13
# 3        Categoría12
# 4        Categoría11
#             ...
# 26577     Categoría7
# 26578     Categoría7
# 26579     Categoría7
# 26580     Categoría7
# 26581     Categoría7
# Name: review_scores_location, Length: 26582, dtype: category
# Categories (13, object): ['Categoría1' < 'Categoría2' < 'Categoría3' < 'Categoría4' ... 'Categoría10' < 'Categoría11' < 'Categoría12' < 'Categoria13']

# %%
#Obtengo un análisis univariado de una variable categórica en específico  
variable_3 = freq_tbl(mexico['review_scores_location'])
variable_3
# Out:
#    review_scores_location  frequency  percentage  cumulative_perc
# 0             Categoria13       8601    0.323565         0.335073
# 1              Categoría7       4556    0.171394         0.512564
# 2             Categoría10       2994    0.112633         0.629203
# 3             Categoría12       2370    0.089158         0.721532
# 4             Categoría11       1999    0.075201         0.799408
# 5              Categoría9       1212    0.045595         0.846624
# 6              Categoría8       1093    0.041118         0.889205
# 7              Categoría5        703    0.026446         0.916592
# 8              Categoría6        640    0.024076         0.941525
# 9              Categoría3        592    0.022271         0.964588
# 10             Categoría4        454    0.017079         0.982274
# 11             Categoría2        240    0.009029         0.991624
# 12             Categoría1        215    0.008088         1.000000

# %%
#Elimino las columnas "procentage" y "cumulative_perc" para trabajar con las fecuencias
variable_3_2 = variable_3.drop(['percentage', 'cumulative_perc'], axis=1)
variable_3_2
# Out:
#    review_scores_location  frequency
# 0             Categoria13       8601
# 1              Categoría7       4556
# 2             Categoría10       2994
# 3             Categoría12       2370
# 4             Categoría11       1999
# 5              Categoría9       1212
# 6              Categoría8       1093
# 7              Categoría5        703
# 8              Categoría6        640
# 9              Categoría3        592
# 10             Categoría4        454
# 11             Categoría2        240
# 12             Categoría1        215

# %%
filtro_3 = variable_3_2[variable_3_2['frequency'] > 100]
filtro_3
# Out:
#    review_scores_location  frequency
# 0             Categoria13       8601
# 1              Categoría7       4556
# 2             Categoría10       2994
# 3             Categoría12       2370
# 4             Categoría11       1999
# 5              Categoría9       1212
# 6              Categoría8       1093
# 7              Categoría5        703
# 8              Categoría6        640
# 9              Categoría3        592
# 10             Categoría4        454
# 11             Categoría2        240
# 12             Categoría1        215

# %%
#Ajusto el indice de mi DataFrame
filtro_i3 = filtro_3.set_index("review_scores_location")
filtro_i3
# Out:
#                         frequency
# review_scores_location
# Categoria13                  8601
# Categoría7                   4556
# Categoría10                  2994
# Categoría12                  2370
# Categoría11                  1999
# Categoría9                   1212
# Categoría8                   1093
# Categoría5                    703
# Categoría6                    640
# Categoría3                    592
# Categoría4                    454
# Categoría2                    240
# Categoría1                    215

# %%
#Realizamos grafico de barras del Dataframe filtrado
filtro_i3.plot(kind = 'bar', width=0.8, figsize=(10,4), color = "red")
plt.title('Puntuacion de locacion')
plt.xlabel('Categoria')
plt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')

# %%
mexico['review_scores_value'].info()
n = 8021
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 26582 entries, 0 to 26581
# Series name: review_scores_value
# Non-Null Count  Dtype
# --------------  -----
# 26582 non-null  float64
# dtypes: float64(1)
# memory usage: 207.8 KB

# %%
Min = mexico['review_scores_value'].min()  
Max = mexico['review_scores_value'].max()  
Limites = [Min,Max]
Limites
# Out:
# [4.38, 5.0]

# %%
R = Max - Min
R
# Out:
# 0.6200000000000001

# %%
ni = 1+3.32*np.log10(n)
ni
# Out:
# 13.96203867424906

# %%
# Ver resultado
intervalos = np.linspace(4.23, 5.0, 14) #Número de clases más uno
intervalos
# Out:
# array([4.23      , 4.28923077, 4.34846154, 4.40769231, 4.46692308,
#        4.52615385, 4.58538462, 4.64461538, 4.70384615, 4.76307692,
#        4.82230769, 4.88153846, 4.94076923, 5.        ])

# %%
categorias = ["Categoría1", "Categoría2", "Categoría3", "Categoría4",
              "Categoría5", "Categoría6", "Categoría7", "Categoría8",
              "Categoría9","Categoría10","Categoría11","Categoría12",
              "Categoria13"]

# %%
mexico['review_scores_value'] = pd.cut(x = mexico['review_scores_value'], bins = intervalos, labels = categorias)
mexico['review_scores_value']
# Out:
# 0         Categoría8
# 1         Categoría5
# 2        Categoría12
# 3        Categoría12
# 4        Categoría10
#             ...
# 26577     Categoría8
# 26578     Categoría8
# 26579     Categoría8
# 26580     Categoría8
# 26581     Categoría8
# Name: review_scores_value, Length: 26582, dtype: category
# Categories (13, object): ['Categoría1' < 'Categoría2' < 'Categoría3' < 'Categoría4' ... 'Categoría10' < 'Categoría11' < 'Categoría12' < 'Categoria13']

# %%
#Obtengo un análisis univariado de una variable categórica en específico  
variable_4 = freq_tbl(mexico['review_scores_value'])
variable_4
# Out:
#    review_scores_value  frequency  percentage  cumulative_perc
# 0           Categoría8       5432    0.204349         0.204349
# 1          Categoria13       4940    0.185840         0.390189
# 2          Categoría10       4807    0.180837         0.571026
# 3          Categoría11       3195    0.120194         0.691220
# 4          Categoría12       2596    0.097660         0.788880
# 5           Categoría9       2319    0.087239         0.876119
# 6           Categoría7       1157    0.043526         0.919645
# 7           Categoría5        802    0.030171         0.949816
# 8           Categoría6        755    0.028403         0.978218
# 9           Categoría4        374    0.014070         0.992288
# 10          Categoría3        205    0.007712         1.000000
# 11          Categoría1          0    0.000000         1.000000
# 12          Categoría2          0    0.000000         1.000000

# %%
#Elimino las columnas "procentage" y "cumulative_perc" para trabajar con las fecuencias
variable_4_2 = variable_4.drop(['percentage', 'cumulative_perc'], axis=1)
variable_4_2
# Out:
#    review_scores_value  frequency
# 0           Categoría8       5432
# 1          Categoria13       4940
# 2          Categoría10       4807
# 3          Categoría11       3195
# 4          Categoría12       2596
# 5           Categoría9       2319
# 6           Categoría7       1157
# 7           Categoría5        802
# 8           Categoría6        755
# 9           Categoría4        374
# 10          Categoría3        205
# 11          Categoría1          0
# 12          Categoría2          0

# %%
filtro_4 = variable_4_2[variable_4_2['frequency'] > 100]
filtro_4
# Out:
#    review_scores_value  frequency
# 0           Categoría8       5432
# 1          Categoria13       4940
# 2          Categoría10       4807
# 3          Categoría11       3195
# 4          Categoría12       2596
# 5           Categoría9       2319
# 6           Categoría7       1157
# 7           Categoría5        802
# 8           Categoría6        755
# 9           Categoría4        374
# 10          Categoría3        205

# %%
#Ajusto el indice de mi DataFrame
filtro_i4 = filtro_4.set_index("review_scores_value")
filtro_i4
# Out:
#                      frequency
# review_scores_value
# Categoría8                5432
# Categoria13               4940
# Categoría10               4807
# Categoría11               3195
# Categoría12               2596
# Categoría9                2319
# Categoría7                1157
# Categoría5                 802
# Categoría6                 755
# Categoría4                 374
# Categoría3                 205

# %%
#Realizamos grafico de área del dataframe filtrado
filtro_i4.plot(kind='area', figsize=(10,4), alpha = 0.5)
# Out:
# <Axes: xlabel='review_scores_value'>

# %%
mexico['reviews_per_month'].info()
n = 8021
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 26582 entries, 0 to 26581
# Series name: reviews_per_month
# Non-Null Count  Dtype
# --------------  -----
# 26582 non-null  float64
# dtypes: float64(1)
# memory usage: 207.8 KB

# %%
Min = mexico['reviews_per_month'].min()  
Max = mexico['reviews_per_month'].max()  
Limites = [Min,Max]
Limites
# Out:
# [0.01, 4.72]

# %%
R = Max - Min
R
# Out:
# 4.71

# %%
ni = 1+3.32*np.log10(n)
ni
# Out:
# 13.96203867424906

# %%
i = R/ni
i
# Out:
# 0.33734328559674504

# %%
# Ver resultado
intervalos = np.linspace(0.01, 2.34, 14) #Número de clases más uno
intervalos
# Out:
# array([0.01      , 0.18923077, 0.36846154, 0.54769231, 0.72692308,
#        0.90615385, 1.08538462, 1.26461538, 1.44384615, 1.62307692,
#        1.80230769, 1.98153846, 2.16076923, 2.34      ])

# %%
categorias = ["Categoría1", "Categoría2", "Categoría3", "Categoría4",
              "Categoría5", "Categoría6", "Categoría7", "Categoría8",
              "Categoría9","Categoría10","Categoría11","Categoría12",
              "Categoria13"]

# %%
mexico['reviews_per_month'] = pd.cut(x = mexico['reviews_per_month'], bins = intervalos, labels = categorias)
mexico['reviews_per_month']
# Out:
# 0        Categoría10
# 1         Categoría3
# 2         Categoría2
# 3         Categoría5
# 4         Categoría1
#             ...
# 26577    Categoría10
# 26578    Categoría10
# 26579    Categoría10
# 26580    Categoría10
# 26581    Categoría10
# Name: reviews_per_month, Length: 26582, dtype: category
# Categories (13, object): ['Categoría1' < 'Categoría2' < 'Categoría3' < 'Categoría4' ... 'Categoría10' < 'Categoría11' < 'Categoría12' < 'Categoria13']

# %%
#Obtengo un análisis univariado de una variable categórica en específico  
variable_5 = freq_tbl(mexico['reviews_per_month'])
variable_5
# Out:
#    reviews_per_month  frequency  percentage  cumulative_perc
# 0        Categoría10       4416    0.166127         0.202597
# 1         Categoría1       2891    0.108758         0.335230
# 2         Categoría9       2277    0.085659         0.439694
# 3         Categoría2       2177    0.081898         0.539570
# 4         Categoría3       1746    0.065684         0.619672
# 5         Categoría4       1481    0.055714         0.687618
# 6         Categoría6       1422    0.053495         0.752856
# 7         Categoría5       1269    0.047739         0.811075
# 8         Categoría7       1009    0.037958         0.857366
# 9         Categoría8        954    0.035889         0.901133
# 10       Categoría12        790    0.029719         0.937377
# 11       Categoría11        751    0.028252         0.971831
# 12       Categoria13        614    0.023098         1.000000

# %%
#Elimino las columnas "procentage" y "cumulative_perc" para trabajar con las fecuencias
variable_5_2 = variable_5.drop(['percentage', 'cumulative_perc'], axis=1)
variable_5_2
# Out:
#    reviews_per_month  frequency
# 0        Categoría10       4416
# 1         Categoría1       2891
# 2         Categoría9       2277
# 3         Categoría2       2177
# 4         Categoría3       1746
# 5         Categoría4       1481
# 6         Categoría6       1422
# 7         Categoría5       1269
# 8         Categoría7       1009
# 9         Categoría8        954
# 10       Categoría12        790
# 11       Categoría11        751
# 12       Categoria13        614

# %%
filtro_5 = variable_5_2[variable_1_2['frequency'] > 100]
filtro_5
# Out:
#    reviews_per_month  frequency
# 0        Categoría10       4416
# 1         Categoría1       2891
# 2         Categoría9       2277
# 3         Categoría2       2177
# 4         Categoría3       1746
# 5         Categoría4       1481
# 6         Categoría6       1422
# 7         Categoría5       1269
# 8         Categoría7       1009
# 9         Categoría8        954
# 10       Categoría12        790
# 11       Categoría11        751
# 12       Categoria13        614

# %%
#Ajusto el indice de mi DataFrame
filtro_i5 = filtro_5.set_index('reviews_per_month')
filtro_i5
# Out:
#                    frequency
# reviews_per_month
# Categoría10             4416
# Categoría1              2891
# Categoría9              2277
# Categoría2              2177
# Categoría3              1746
# Categoría4              1481
# Categoría6              1422
# Categoría5              1269
# Categoría7              1009
# Categoría8               954
# Categoría12              790
# Categoría11              751
# Categoria13              614

# %%
#Realizamos grafico de área del dataframe filtrado
filtro_i5.plot(kind='area', figsize=(10,4), alpha = 0.5)
# Out:
# <Axes: xlabel='reviews_per_month'>

# %%
mexico['review_scores_communication'].info()
n = 8021
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 26582 entries, 0 to 26581
# Series name: review_scores_communication
# Non-Null Count  Dtype
# --------------  -----
# 26582 non-null  float64
# dtypes: float64(1)
# memory usage: 207.8 KB

# %%
Min = mexico['review_scores_communication'].min()  
Max = mexico['review_scores_communication'].max()  
Limites = [Min,Max]
Limites
# Out:
# [4.5, 5.0]

# %%
R = Max - Min
R
# Out:
# 0.5

# %%
ni = 1+3.32*np.log10(n)
ni
# Out:
# 13.96203867424906

# %%
i = R/ni
i
# Out:
# 0.03581138912916614

# %%
# Ver resultado
intervalos = np.linspace(4.76, 5.0, 14) #Número de clases más uno
intervalos
# Out:
# array([4.76      , 4.77846154, 4.79692308, 4.81538462, 4.83384615,
#        4.85230769, 4.87076923, 4.88923077, 4.90769231, 4.92615385,
#        4.94461538, 4.96307692, 4.98153846, 5.        ])

# %%
categorias = ["Categoría1", "Categoría2", "Categoría3", "Categoría4",
              "Categoría5", "Categoría6", "Categoría7", "Categoría8",
              "Categoría9","Categoría10","Categoría11","Categoría12",
              "Categoria13"]

# %%
mexico['review_scores_communication'] = pd.cut(x = mexico['review_scores_communication'], bins = intervalos, labels = categorias)
mexico['review_scores_communication']
# Out:
# 0         Categoría3
# 1         Categoría2
# 2         Categoría9
# 3        Categoría12
# 4                NaN
#             ...
# 26577     Categoría3
# 26578     Categoría3
# 26579     Categoría3
# 26580     Categoría3
# 26581     Categoría3
# Name: review_scores_communication, Length: 26582, dtype: category
# Categories (13, object): ['Categoría1' < 'Categoría2' < 'Categoría3' < 'Categoría4' ... 'Categoría10' < 'Categoría11' < 'Categoría12' < 'Categoria13']

# %%
#Obtengo un análisis univariado de una variable categórica en específico  
variable_6 = freq_tbl(mexico['review_scores_communication'])
variable_6
# Out:
#    review_scores_communication  frequency  percentage  cumulative_perc
# 0                  Categoria13       7471    0.281055         0.318050
# 1                   Categoría3       4339    0.163231         0.502767
# 2                   Categoría8       2637    0.099202         0.615028
# 3                  Categoría11       1417    0.053307         0.675351
# 4                  Categoría10       1387    0.052178         0.734398
# 5                  Categoría12       1318    0.049582         0.790507
# 6                   Categoría9       1283    0.048266         0.845126
# 7                   Categoría6        866    0.032578         0.881992
# 8                   Categoría4        787    0.029607         0.915496
# 9                   Categoría7        654    0.024603         0.943338
# 10                  Categoría5        649    0.024415         0.970966
# 11                  Categoría2        499    0.018772         0.992209
# ...

# %%
#Elimino las columnas "procentage" y "cumulative_perc" para trabajar con las fecuencias
variable_6_2 = variable_6.drop(['percentage', 'cumulative_perc'], axis=1)
variable_6_2
# Out:
#    review_scores_communication  frequency
# 0                  Categoria13       7471
# 1                   Categoría3       4339
# 2                   Categoría8       2637
# 3                  Categoría11       1417
# 4                  Categoría10       1387
# 5                  Categoría12       1318
# 6                   Categoría9       1283
# 7                   Categoría6        866
# 8                   Categoría4        787
# 9                   Categoría7        654
# 10                  Categoría5        649
# 11                  Categoría2        499
# 12                  Categoría1        183

# %%
filtro_6 = variable_6_2[variable_6_2['frequency'] > 100]
filtro_6
# Out:
#    review_scores_communication  frequency
# 0                  Categoria13       7471
# 1                   Categoría3       4339
# 2                   Categoría8       2637
# 3                  Categoría11       1417
# 4                  Categoría10       1387
# 5                  Categoría12       1318
# 6                   Categoría9       1283
# 7                   Categoría6        866
# 8                   Categoría4        787
# 9                   Categoría7        654
# 10                  Categoría5        649
# 11                  Categoría2        499
# 12                  Categoría1        183

# %%
#Ajusto el indice de mi DataFrame
filtro_i6 = filtro_6.set_index('review_scores_communication')
filtro_i6
# Out:
#                              frequency
# review_scores_communication
# Categoria13                       7471
# Categoría3                        4339
# Categoría8                        2637
# Categoría11                       1417
# Categoría10                       1387
# Categoría12                       1318
# Categoría9                        1283
# Categoría6                         866
# Categoría4                         787
# Categoría7                         654
# Categoría5                         649
# Categoría2                         499
# Categoría1                         183

# %%
#Realizamos grafico de área del dataframe filtrado
filtro_i6.plot(kind='area', figsize=(10,4), alpha = 0.5)
# Out:
# <Axes: xlabel='review_scores_communication'>

# %%
mexico['review_scores_checkin'].info()
n = 8021
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 26582 entries, 0 to 26581
# Series name: review_scores_checkin
# Non-Null Count  Dtype
# --------------  -----
# 26582 non-null  float64
# dtypes: float64(1)
# memory usage: 207.8 KB

# %%
Min = mexico['review_scores_checkin'].min()  
Max = mexico['review_scores_checkin'].max()  
Limites = [Min,Max]
Limites
# Out:
# [4.5, 5.0]

# %%
R = Max - Min
R
# Out:
# 0.5

# %%
ni = 1+3.32*np.log10(n)
ni
# Out:
# 13.96203867424906

# %%
i = R/ni
i
# Out:
# 0.03581138912916614

# %%
# Ver resultado
intervalos = np.linspace(4.5, 5.0, 14) #Número de clases más uno
intervalos
# Out:
# array([4.5       , 4.53846154, 4.57692308, 4.61538462, 4.65384615,
#        4.69230769, 4.73076923, 4.76923077, 4.80769231, 4.84615385,
#        4.88461538, 4.92307692, 4.96153846, 5.        ])

# %%
categorias = ["Categoría1", "Categoría2", "Categoría3", "Categoría4",
              "Categoría5", "Categoría6", "Categoría7", "Categoría8",
              "Categoría9","Categoría10","Categoría11","Categoría12",
              "Categoria13"]

# %%
mexico['review_scores_checkin'] = pd.cut(x = mexico['review_scores_checkin'], bins = intervalos, labels = categorias)
mexico['review_scores_checkin']
# Out:
# 0         Categoría8
# 1        Categoría10
# 2        Categoría12
# 3        Categoría12
# 4        Categoria13
#             ...
# 26577     Categoría8
# 26578     Categoría8
# 26579     Categoría8
# 26580     Categoría8
# 26581     Categoría8
# Name: review_scores_checkin, Length: 26582, dtype: category
# Categories (13, object): ['Categoría1' < 'Categoría2' < 'Categoría3' < 'Categoría4' ... 'Categoría10' < 'Categoría11' < 'Categoría12' < 'Categoria13']

# %%
#Obtengo un análisis univariado de una variable categórica en específico  
variable_7 = freq_tbl(mexico['review_scores_checkin'])
variable_7
# Out:
#    review_scores_checkin  frequency  percentage  cumulative_perc
# 0            Categoria13       8289    0.311828         0.315531
# 1             Categoría8       4826    0.181551         0.499239
# 2            Categoría11       3949    0.148559         0.649562
# 3            Categoría12       3037    0.114250         0.765169
# 4            Categoría10       2021    0.076029         0.842101
# 5             Categoría9       1441    0.054210         0.896955
# 6             Categoría7        677    0.025468         0.922726
# 7             Categoría6        625    0.023512         0.946517
# 8             Categoría5        608    0.022873         0.969661
# 9             Categoría4        302    0.011361         0.981157
# 10            Categoría3        255    0.009593         0.990864
# 11            Categoría2        197    0.007411         0.998363
# 12            Categoría1         43    0.001618         1.000000

# %%
#Elimino las columnas "procentage" y "cumulative_perc" para trabajar con las fecuencias
variable_7_2 = variable_7.drop(['percentage', 'cumulative_perc'], axis=1)
variable_7_2
# Out:
#    review_scores_checkin  frequency
# 0            Categoria13       8289
# 1             Categoría8       4826
# 2            Categoría11       3949
# 3            Categoría12       3037
# 4            Categoría10       2021
# 5             Categoría9       1441
# 6             Categoría7        677
# 7             Categoría6        625
# 8             Categoría5        608
# 9             Categoría4        302
# 10            Categoría3        255
# 11            Categoría2        197
# 12            Categoría1         43

# %%
filtro_7 = variable_7_2[variable_7_2['frequency'] > 100]
filtro_7
# Out:
#    review_scores_checkin  frequency
# 0            Categoria13       8289
# 1             Categoría8       4826
# 2            Categoría11       3949
# 3            Categoría12       3037
# 4            Categoría10       2021
# 5             Categoría9       1441
# 6             Categoría7        677
# 7             Categoría6        625
# 8             Categoría5        608
# 9             Categoría4        302
# 10            Categoría3        255
# 11            Categoría2        197

# %%
#Ajusto el indice de mi DataFrame
filtro_i7 = filtro_7.set_index('review_scores_checkin')
filtro_i7
# Out:
#                        frequency
# review_scores_checkin
# Categoria13                 8289
# Categoría8                  4826
# Categoría11                 3949
# Categoría12                 3037
# Categoría10                 2021
# Categoría9                  1441
# Categoría7                   677
# Categoría6                   625
# Categoría5                   608
# Categoría4                   302
# Categoría3                   255
# Categoría2                   197

# %%
#Realizamos grafico de barras del Dataframe filtrado
filtro_i7.plot(kind = 'bar', width=0.8, figsize=(10,4), color = "red")
plt.title('Evaluación de reseñas')
plt.xlabel('Categoria')
plt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')

# %%
mexico['review_scores_cleanliness'].info()
n = 8021
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 26582 entries, 0 to 26581
# Series name: review_scores_cleanliness
# Non-Null Count  Dtype
# --------------  -----
# 26582 non-null  float64
# dtypes: float64(1)
# memory usage: 207.8 KB

# %%
Min = mexico['review_scores_cleanliness'].min()  
Max = mexico['review_scores_cleanliness'].max()  
Limites = [Min,Max]
Limites
# Out:
# [4.43, 5.0]

# %%
R = Max - Min
R
# Out:
# 0.5700000000000003

# %%
ni = 1+3.32*np.log10(n)
ni
# Out:
# 13.96203867424906

# %%
i = R/ni
i
# Out:
# 0.04082498360724942

# %%
# Ver resultado
intervalos = np.linspace(4.13, 5.0, 14) #Número de clases más uno
intervalos
# Out:
# array([4.13      , 4.19692308, 4.26384615, 4.33076923, 4.39769231,
#        4.46461538, 4.53153846, 4.59846154, 4.66538462, 4.73230769,
#        4.79923077, 4.86615385, 4.93307692, 5.        ])

# %%
categorias = ["Categoría1", "Categoría2", "Categoría3", "Categoría4",
              "Categoría5", "Categoría6", "Categoría7", "Categoría8",
              "Categoría9","Categoría10","Categoría11","Categoría12",
              "Categoria13"]

# %%
mexico['review_scores_cleanliness'] = pd.cut(x = mexico['review_scores_cleanliness'], bins = intervalos, labels = categorias)
mexico['review_scores_cleanliness']
# Out:
# 0        Categoría11
# 1         Categoría9
# 2        Categoría10
# 3        Categoria13
# 4        Categoria13
#             ...
# 26577    Categoría11
# 26578    Categoría11
# 26579    Categoría11
# 26580    Categoría11
# 26581    Categoría11
# Name: review_scores_cleanliness, Length: 26582, dtype: category
# Categories (13, object): ['Categoría1' < 'Categoría2' < 'Categoría3' < 'Categoría4' ... 'Categoría10' < 'Categoría11' < 'Categoría12' < 'Categoria13']

# %%
#Obtengo un análisis univariado de una variable categórica en específico  
variable_8 = freq_tbl(mexico['review_scores_cleanliness'])
variable_8
# Out:
#    review_scores_cleanliness  frequency  percentage  cumulative_perc
# 0                Categoría11       8845    0.332744         0.332744
# 1                Categoria13       7183    0.270220         0.602964
# 2                Categoría12       3830    0.144082         0.747047
# 3                Categoría10       2088    0.078549         0.825596
# 4                 Categoría9       1885    0.070913         0.896509
# 5                 Categoría8       1056    0.039726         0.936235
# 6                 Categoría6        802    0.030171         0.966406
# 7                 Categoría7        653    0.024565         0.990971
# 8                 Categoría5        240    0.009029         1.000000
# 9                 Categoría1          0    0.000000         1.000000
# 10                Categoría2          0    0.000000         1.000000
# 11                Categoría3          0    0.000000         1.000000
# 12                Categoría4          0    0.000000         1.000000

# %%
#Elimino las columnas "procentage" y "cumulative_perc" para trabajar con las fecuencias
variable_8_2 = variable_8.drop(['percentage', 'cumulative_perc'], axis=1)
variable_8_2
# Out:
#    review_scores_cleanliness  frequency
# 0                Categoría11       8845
# 1                Categoria13       7183
# 2                Categoría12       3830
# 3                Categoría10       2088
# 4                 Categoría9       1885
# 5                 Categoría8       1056
# 6                 Categoría6        802
# 7                 Categoría7        653
# 8                 Categoría5        240
# 9                 Categoría1          0
# 10                Categoría2          0
# 11                Categoría3          0
# 12                Categoría4          0

# %%
filtro_8 = variable_8_2[variable_8_2['frequency'] > 100]
filtro_8
# Out:
#   review_scores_cleanliness  frequency
# 0               Categoría11       8845
# 1               Categoria13       7183
# 2               Categoría12       3830
# 3               Categoría10       2088
# 4                Categoría9       1885
# 5                Categoría8       1056
# 6                Categoría6        802
# 7                Categoría7        653
# 8                Categoría5        240

# %%
#Ajusto el indice de mi DataFrame
filtro_i8 = filtro_8.set_index('review_scores_cleanliness')
filtro_i8
# Out:
#                            frequency
# review_scores_cleanliness
# Categoría11                     8845
# Categoria13                     7183
# Categoría12                     3830
# Categoría10                     2088
# Categoría9                      1885
# Categoría8                      1056
# Categoría6                       802
# Categoría7                       653
# Categoría5                       240

# %%
#Realizamos grafico de barras del Dataframe filtrado
filtro_i8.plot(kind = 'bar', width=0.8, figsize=(10,4), color = "red")
plt.title('Puntuación de limpieza')
plt.xlabel('Categoria')
plt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')

# %%
mexico['review_scores_accuracy'].info()
n = 8021
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 26582 entries, 0 to 26581
# Series name: review_scores_accuracy
# Non-Null Count  Dtype
# --------------  -----
# 26582 non-null  float64
# dtypes: float64(1)
# memory usage: 207.8 KB

# %%
Min = mexico['review_scores_accuracy'].min()  
Max = mexico['review_scores_accuracy'].max()  
Limites = [Min,Max]
Limites
# Out:
# [4.52, 5.0]

# %%
R = Max - Min
R
# Out:
# 0.4800000000000004

# %%
ni = 1+3.32*np.log10(n)
ni
# Out:
# 13.96203867424906

# %%
i = R/ni
i
# Out:
# 0.03437893356399952

# %%
# Ver resultado
intervalos = np.linspace(4.4, 5.0, 14) #Número de clases más uno
intervalos
# Out:
# array([4.4       , 4.44615385, 4.49230769, 4.53846154, 4.58461538,
#        4.63076923, 4.67692308, 4.72307692, 4.76923077, 4.81538462,
#        4.86153846, 4.90769231, 4.95384615, 5.        ])

# %%
categorias = ["Categoría1", "Categoría2", "Categoría3", "Categoría4",
              "Categoría5", "Categoría6", "Categoría7", "Categoría8",
              "Categoría9","Categoría10","Categoría11","Categoría12",
              "Categoria13"]

# %%
mexico['review_scores_accuracy'] = pd.cut(x = mexico['review_scores_accuracy'], bins = intervalos, labels = categorias)
mexico['review_scores_accuracy']
# Out:
# 0        Categoría11
# 1         Categoría4
# 2         Categoría9
# 3        Categoría11
# 4        Categoria13
#             ...
# 26577    Categoría11
# 26578    Categoría11
# 26579    Categoría11
# 26580    Categoría11
# 26581    Categoría11
# Name: review_scores_accuracy, Length: 26582, dtype: category
# Categories (13, object): ['Categoría1' < 'Categoría2' < 'Categoría3' < 'Categoría4' ... 'Categoría10' < 'Categoría11' < 'Categoría12' < 'Categoria13']

# %%
#Obtengo un análisis univariado de una variable categórica en específico  
variable_9 = freq_tbl(mexico['review_scores_accuracy'])
variable_9
# Out:
#    review_scores_accuracy  frequency  percentage  cumulative_perc
# 0             Categoria13       6898    0.259499         0.259499
# 1             Categoría11       6136    0.230833         0.490332
# 2              Categoría9       3997    0.150365         0.640697
# 3             Categoría12       3130    0.117749         0.758446
# 4             Categoría10       2484    0.093447         0.851892
# 5              Categoría8       1243    0.046761         0.898653
# 6              Categoría7        901    0.033895         0.932548
# 7              Categoría6        764    0.028741         0.961290
# 8              Categoría5        551    0.020728         0.982018
# 9              Categoría4        387    0.014559         0.996577
# 10             Categoría3         91    0.003423         1.000000
# 11             Categoría1          0    0.000000         1.000000
# 12             Categoría2          0    0.000000         1.000000

# %%
#Elimino las columnas "procentage" y "cumulative_perc" para trabajar con las fecuencias
variable_9_2 = variable_9.drop(['percentage', 'cumulative_perc'], axis=1)
variable_9_2
# Out:
#    review_scores_accuracy  frequency
# 0             Categoria13       6898
# 1             Categoría11       6136
# 2              Categoría9       3997
# 3             Categoría12       3130
# 4             Categoría10       2484
# 5              Categoría8       1243
# 6              Categoría7        901
# 7              Categoría6        764
# 8              Categoría5        551
# 9              Categoría4        387
# 10             Categoría3         91
# 11             Categoría1          0
# 12             Categoría2          0

# %%
filtro_9 = variable_9_2[variable_9_2['frequency'] > 100]
filtro_9
# Out:
#   review_scores_accuracy  frequency
# 0            Categoria13       6898
# 1            Categoría11       6136
# 2             Categoría9       3997
# 3            Categoría12       3130
# 4            Categoría10       2484
# 5             Categoría8       1243
# 6             Categoría7        901
# 7             Categoría6        764
# 8             Categoría5        551
# 9             Categoría4        387

# %%
#Ajusto el indice de mi DataFrame
filtro_i9 = filtro_9.set_index('review_scores_accuracy')
filtro_i9
# Out:
#                         frequency
# review_scores_accuracy
# Categoria13                  6898
# Categoría11                  6136
# Categoría9                   3997
# Categoría12                  3130
# Categoría10                  2484
# Categoría8                   1243
# Categoría7                    901
# Categoría6                    764
# Categoría5                    551
# Categoría4                    387

# %%
#Realizamos grafico de barras del Dataframe filtrado
filtro_i9.plot(kind = 'bar', width=0.8, figsize=(10,4), color = "red")
plt.title('Evaluación de precisión')
plt.xlabel('Categoria')
plt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')

# %%
# Eliminar % y convertir a número
mexico["host_response_rate"] = mexico["host_response_rate"].str.replace('%', '', regex=True).astype(float) / 100

# %%
mexico['host_response_rate'].info()
n=8021
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 26582 entries, 0 to 26581
# Series name: host_response_rate
# Non-Null Count  Dtype
# --------------  -----
# 26582 non-null  float64
# dtypes: float64(1)
# memory usage: 207.8 KB

# %%
Min = mexico["host_response_rate"].min()  
Max = mexico["host_response_rate"].max()  
Limites = [Min,Max]
Limites
# Out:
# [0.0, 1.0]

# %%
R = Max - Min
R
# Out:
# 1.0

# %%
ni = 1+3.32*np.log10(n)
ni
# Out:
# 13.96203867424906

# %%
i = R/ni
i
# Out:
# 0.07162277825833228

# %%
# Ver resultado
intervalos = np.linspace(0.0, 1.0, 13) #Número de clases más uno
intervalos
# Out:
# array([0.        , 0.08333333, 0.16666667, 0.25      , 0.33333333,
#        0.41666667, 0.5       , 0.58333333, 0.66666667, 0.75      ,
#        0.83333333, 0.91666667, 1.        ])

# %%
categorias = ["Categoría1", "Categoría2", "Categoría3", "Categoría4",
              "Categoría5", "Categoría6", "Categoría7", "Categoría8",
              "Categoría9","Categoría10","Categoría11","Categoría12",]

# %%
mexico["host_response_rate"] = pd.cut(x = mexico["host_response_rate"], bins = intervalos, labels = categorias)
mexico["host_response_rate"]
# Out:
# 0                NaN
# 1        Categoría12
# 2         Categoría9
# 3        Categoría12
# 4        Categoría12
#             ...
# 26577    Categoría12
# 26578    Categoría12
# 26579    Categoría12
# 26580    Categoría12
# 26581    Categoría12
# Name: host_response_rate, Length: 26582, dtype: category
# Categories (12, object): ['Categoría1' < 'Categoría2' < 'Categoría3' < 'Categoría4' ... 'Categoría9' < 'Categoría10' < 'Categoría11' < 'Categoría12']

# %%
#Obtengo un análisis univariado de una variable categórica en específico  
variable_10 = freq_tbl(mexico["host_response_rate"])
variable_10
# Out:
#    host_response_rate  frequency  percentage  cumulative_perc
# 0         Categoría12      23477    0.883192         0.902441
# 1         Categoría11        981    0.036905         0.940150
# 2         Categoría10        373    0.014032         0.954488
# 3          Categoría9        323    0.012151         0.966904
# 4          Categoría6        224    0.008427         0.975514
# 5          Categoría4        124    0.004665         0.980281
# 6          Categoría1        119    0.004477         0.984855
# 7          Categoría8         95    0.003574         0.988507
# 8          Categoría3         94    0.003536         0.992120
# 9          Categoría2         84    0.003160         0.995349
# 10         Categoría5         68    0.002558         0.997963
# 11         Categoría7         53    0.001994         1.000000

# %%
#Elimino las columnas "procentage" y "cumulative_perc" para trabajar con las fecuencias
variable_10_2 = variable_10.drop(['percentage', 'cumulative_perc'], axis=1)
variable_10_2
# Out:
#    host_response_rate  frequency
# 0         Categoría12      23477
# 1         Categoría11        981
# 2         Categoría10        373
# 3          Categoría9        323
# 4          Categoría6        224
# 5          Categoría4        124
# 6          Categoría1        119
# 7          Categoría8         95
# 8          Categoría3         94
# 9          Categoría2         84
# 10         Categoría5         68
# 11         Categoría7         53

# %%
filtro_10 = variable_10_2[variable_10_2['frequency'] > 100]
filtro_10
# Out:
#   host_response_rate  frequency
# 0        Categoría12      23477
# 1        Categoría11        981
# 2        Categoría10        373
# 3         Categoría9        323
# 4         Categoría6        224
# 5         Categoría4        124
# 6         Categoría1        119

# %%
#Ajusto el indice de mi DataFrame
filtro_i10 = filtro_10.set_index("host_response_rate")
filtro_i10
# Out:
#                     frequency
# host_response_rate
# Categoría12             23477
# Categoría11               981
# Categoría10               373
# Categoría9                323
# Categoría6                224
# Categoría4                124
# Categoría1                119

# %%
#Realizamos grafico de barras del Dataframe filtrado
filtro_i10.plot(kind = 'bar', width=0.8, figsize=(10,4), color = "red")
plt.title('Tiempo de respuesta del host')
plt.xlabel('Categoria')
plt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')

# %%
# Eliminar % y convertir a número
mexico["host_acceptance_rate"] = mexico["host_acceptance_rate"].str.replace('%', '', regex=True).astype(float) / 100 
mexico['host_acceptance_rate'].info()
n = 8021
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 26582 entries, 0 to 26581
# Series name: host_acceptance_rate
# Non-Null Count  Dtype
# --------------  -----
# 26582 non-null  float64
# dtypes: float64(1)
# memory usage: 207.8 KB

# %%
Min = mexico["host_acceptance_rate"].min()  
Max = mexico["host_acceptance_rate"].max()  
Limites = [Min,Max]
Limites
# Out:
# [0.0, 1.0]

# %%
R = Max - Min
R
# Out:
# 1.0

# %%
#Calcular el número de Intervalos de Clase (ni). Se aplica la regla de Sturges (Donde “n” el tamaño de la muestra.):
ni = 1+3.32*np.log10(n)
ni
# Out:
# 13.96203867424906

# %%
#Calcular el Ancho del Intervalo ( i )
i = R/ni
i
# Out:
# 0.07162277825833228

# %%
# Ver resultado
intervalos = np.linspace(0.0, 1.0, 13) #Número de clases más uno
intervalos
# Out:
# array([0.        , 0.08333333, 0.16666667, 0.25      , 0.33333333,
#        0.41666667, 0.5       , 0.58333333, 0.66666667, 0.75      ,
#        0.83333333, 0.91666667, 1.        ])

# %%
categorias = ["Categoría1", "Categoría2", "Categoría3", "Categoría4",
              "Categoría5", "Categoría6", "Categoría7", "Categoría8",
              "Categoría9","Categoría10","Categoría11","Categoría12"]

# %%
mexico["host_acceptance_rate"] = pd.cut(x = mexico["host_acceptance_rate"], bins = intervalos, labels = categorias)
mexico["host_acceptance_rate"]
# Out:
# 0        Categoría12
# 1        Categoría12
# 2         Categoría7
# 3        Categoría12
# 4        Categoría12
#             ...
# 26577    Categoría12
# 26578    Categoría12
# 26579    Categoría12
# 26580    Categoría12
# 26581    Categoría12
# Name: host_acceptance_rate, Length: 26582, dtype: category
# Categories (12, object): ['Categoría1' < 'Categoría2' < 'Categoría3' < 'Categoría4' ... 'Categoría9' < 'Categoría10' < 'Categoría11' < 'Categoría12']

# %%
#Obtengo un análisis univariado de una variable categórica en específico  
variable_11 = freq_tbl(mexico["host_acceptance_rate"])
variable_11
# Out:
#    host_acceptance_rate  frequency  percentage  cumulative_perc
# 0           Categoría12      21390    0.804680         0.833009
# 1           Categoría11       1403    0.052780         0.887647
# 2            Categoría9        704    0.026484         0.915063
# 3           Categoría10        678    0.025506         0.941467
# 4            Categoría6        375    0.014107         0.956071
# 5            Categoría4        321    0.012076         0.968572
# 6            Categoría8        226    0.008502         0.977374
# 7            Categoría7        185    0.006960         0.984578
# 8            Categoría3        158    0.005944         0.990731
# 9            Categoría5        137    0.005154         0.996067
# 10           Categoría2         72    0.002709         0.998871
# 11           Categoría1         29    0.001091         1.000000

# %%
#Elimino las columnas "procentage" y "cumulative_perc" para trabajar con las fecuencias
variable_11_2 = variable_11.drop(['percentage', 'cumulative_perc'], axis=1)
variable_11_2
# Out:
#    host_acceptance_rate  frequency
# 0           Categoría12      21390
# 1           Categoría11       1403
# 2            Categoría9        704
# 3           Categoría10        678
# 4            Categoría6        375
# 5            Categoría4        321
# 6            Categoría8        226
# 7            Categoría7        185
# 8            Categoría3        158
# 9            Categoría5        137
# 10           Categoría2         72
# 11           Categoría1         29

# %%
filtro_11 = variable_11_2[variable_11_2['frequency'] > 300]
filtro_11
# Out:
#   host_acceptance_rate  frequency
# 0          Categoría12      21390
# 1          Categoría11       1403
# 2           Categoría9        704
# 3          Categoría10        678
# 4           Categoría6        375
# 5           Categoría4        321

# %%
#Ajusto el indice de mi DataFrame
filtro_i11 = filtro_11.set_index("host_acceptance_rate")
filtro_i11
# Out:
#                       frequency
# host_acceptance_rate
# Categoría12               21390
# Categoría11                1403
# Categoría9                  704
# Categoría10                 678
# Categoría6                  375
# Categoría4                  321

# %%
#Realizamos grafico de área del dataframe filtrado
filtro_i11.plot(kind='area', figsize=(10,4), alpha = 0.5)
# Out:
# <Axes: xlabel='host_acceptance_rate'>

# %%
mexico['host_total_listings_count'].info()
n = 8021
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 26582 entries, 0 to 26581
# Series name: host_total_listings_count
# Non-Null Count  Dtype
# --------------  -----
# 26582 non-null  float64
# dtypes: float64(1)
# memory usage: 207.8 KB

# %%
Min = mexico["host_total_listings_count"].min()  
Max = mexico["host_total_listings_count"].max()  
Limites = [Min,Max]
Limites
# Out:
# [1.0, 39.0]

# %%
#Calcula el rango
R = Max - Min
R
# Out:
# 38.0

# %%
#Calcular el número de Intervalos de Clase (ni). Se aplica la regla de Sturges (Donde “n” el tamaño de la muestra.):
ni = 1+3.32*np.log10(n)
ni
# Out:
# 13.96203867424906

# %%
#Calcular el Ancho del Intervalo ( i )
i = R/ni
i
# Out:
# 2.7216655738166264

# %%
# Ver resultado
intervalos = np.linspace(1.0, 6.0, 13) #Número de clases más uno
intervalos
# Out:
# array([1.        , 1.41666667, 1.83333333, 2.25      , 2.66666667,
#        3.08333333, 3.5       , 3.91666667, 4.33333333, 4.75      ,
#        5.16666667, 5.58333333, 6.        ])

# %%
categorias = ["Categoría1", "Categoría2", "Categoría3", "Categoría4",
              "Categoría5", "Categoría6", "Categoría7", "Categoría8",
              "Categoría9","Categoría10","Categoría11","Categoría12"]

# %%
mexico["host_total_listings_count"] = pd.cut(x = mexico["host_total_listings_count"], bins = intervalos, labels = categorias)
mexico["host_total_listings_count"]
# Out:
# 0                NaN
# 1                NaN
# 2         Categoría8
# 3         Categoría8
# 4                NaN
#             ...
# 26577            NaN
# 26578            NaN
# 26579            NaN
# 26580            NaN
# 26581    Categoría12
# Name: host_total_listings_count, Length: 26582, dtype: category
# Categories (12, object): ['Categoría1' < 'Categoría2' < 'Categoría3' < 'Categoría4' ... 'Categoría9' < 'Categoría10' < 'Categoría11' < 'Categoría12']

# %%
#Obtengo un análisis univariado de una variable categórica en específico  
variable_12 = freq_tbl(mexico["host_total_listings_count"])
variable_12
# Out:
#    host_total_listings_count  frequency  percentage  cumulative_perc
# 0                 Categoría3       3403    0.128019         0.349384
# 1                 Categoría5       2221    0.083553         0.577413
# 2                 Categoría8       1810    0.068091         0.763244
# 3                Categoría10       1286    0.048379         0.895277
# 4                Categoría12       1020    0.038372         1.000000
# 5                 Categoría1          0    0.000000         1.000000
# 6                 Categoría2          0    0.000000         1.000000
# 7                 Categoría4          0    0.000000         1.000000
# 8                 Categoría6          0    0.000000         1.000000
# 9                 Categoría7          0    0.000000         1.000000
# 10                Categoría9          0    0.000000         1.000000
# 11               Categoría11          0    0.000000         1.000000

# %%
#Elimino las columnas "procentage" y "cumulative_perc" para trabajar con las fecuencias
variable_12_2 = variable_12.drop(['percentage', 'cumulative_perc'], axis=1)
variable_12_2
# Out:
#    host_total_listings_count  frequency
# 0                 Categoría3       3403
# 1                 Categoría5       2221
# 2                 Categoría8       1810
# 3                Categoría10       1286
# 4                Categoría12       1020
# 5                 Categoría1          0
# 6                 Categoría2          0
# 7                 Categoría4          0
# 8                 Categoría6          0
# 9                 Categoría7          0
# 10                Categoría9          0
# 11               Categoría11          0

# %%
filtro_12 = variable_12_2[variable_12_2['frequency'] > 165]
filtro_12
# Out:
#   host_total_listings_count  frequency
# 0                Categoría3       3403
# 1                Categoría5       2221
# 2                Categoría8       1810
# 3               Categoría10       1286
# 4               Categoría12       1020

# %%
#Ajusto el indice de mi DataFrame
filtro_i12 = filtro_12.set_index("host_total_listings_count")
filtro_i12
# Out:
#                            frequency
# host_total_listings_count
# Categoría3                      3403
# Categoría5                      2221
# Categoría8                      1810
# Categoría10                     1286
# Categoría12                     1020

# %%
#Realizamos grafico de pastel del dataframe filtrado
filtro_i12["frequency"].plot(kind='pie', figsize=(10,5), shadow=True, autopct="%0.1f %%")
# Out:
# <Axes: ylabel='frequency'>

# %%
mexico['accommodates'].info()
n = 8021
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 26582 entries, 0 to 26581
# Series name: accommodates
# Non-Null Count  Dtype
# --------------  -----
# 26582 non-null  float64
# dtypes: float64(1)
# memory usage: 207.8 KB

# %%
Min = mexico["accommodates"].min()  
Max = mexico["accommodates"].max()  
Limites = [Min,Max]
Limites
# Out:
# [1.0, 7.0]

# %%
#Calcula el rango
R = Max - Min
R
# Out:
# 6.0

# %%
#Calcular el número de Intervalos de Clase (ni). Se aplica la regla de Sturges (Donde “n” el tamaño de la muestra.):
ni = 1+3.32*np.log10(n)
ni
# Out:
# 13.96203867424906

# %%
#Calcular el Ancho del Intervalo ( i )
i = R/ni
i
# Out:
# 0.4297366695499937

# %%
# Ver resultado
intervalos = np.linspace(1.0, 7.0, 13) #Número de clases más uno
intervalos
# Out:
# array([1. , 1.5, 2. , 2.5, 3. , 3.5, 4. , 4.5, 5. , 5.5, 6. , 6.5, 7. ])

# %%
categorias = ["Categoría1", "Categoría2", "Categoría3", "Categoría4",
              "Categoría5", "Categoría6", "Categoría7", "Categoría8",
              "Categoría9","Categoría10","Categoría11","Categoría12"]

# %%
mexico["accommodates"] = pd.cut(x = mexico["accommodates"], bins = intervalos, labels = categorias)
mexico["accommodates"]
# Out:
# 0        Categoría2
# 1        Categoría5
# 2        Categoría6
# 3        Categoría2
# 4        Categoría2
#             ...
# 26577    Categoría6
# 26578    Categoría2
# 26579    Categoría2
# 26580    Categoría2
# 26581    Categoría2
# Name: accommodates, Length: 26582, dtype: category
# Categories (12, object): ['Categoría1' < 'Categoría2' < 'Categoría3' < 'Categoría4' ... 'Categoría9' < 'Categoría10' < 'Categoría11' < 'Categoría12']

# %%
#Obtengo un análisis univariado de una variable categórica en específico  
variable_13 = freq_tbl(mexico["accommodates"])
variable_13
# Out:
#    accommodates  frequency  percentage  cumulative_perc
# 0    Categoría2      10620    0.399518         0.450975
# 1    Categoría6       5690    0.214055         0.692598
# 2    Categoría4       2401    0.090324         0.794556
# 3   Categoría10       1800    0.067715         0.870992
# 4    Categoría8       1375    0.051727         0.929381
# 5    Categoría5       1352    0.050861         0.986793
# 6   Categoría12        311    0.011700         1.000000
# 7    Categoría1          0    0.000000         1.000000
# 8    Categoría3          0    0.000000         1.000000
# 9    Categoría7          0    0.000000         1.000000
# 10   Categoría9          0    0.000000         1.000000
# 11  Categoría11          0    0.000000         1.000000

# %%
#Elimino las columnas "procentage" y "cumulative_perc" para trabajar con las fecuencias
variable_13_2 = variable_13.drop(['percentage', 'cumulative_perc'], axis=1)
variable_13_2
# Out:
#    accommodates  frequency
# 0    Categoría2      10620
# 1    Categoría6       5690
# 2    Categoría4       2401
# 3   Categoría10       1800
# 4    Categoría8       1375
# 5    Categoría5       1352
# 6   Categoría12        311
# 7    Categoría1          0
# 8    Categoría3          0
# 9    Categoría7          0
# 10   Categoría9          0
# 11  Categoría11          0

# %%
filtro_13 = variable_13_2[variable_13_2['frequency'] > 100]
filtro_13
# Out:
#   accommodates  frequency
# 0   Categoría2      10620
# 1   Categoría6       5690
# 2   Categoría4       2401
# 3  Categoría10       1800
# 4   Categoría8       1375
# 5   Categoría5       1352
# 6  Categoría12        311

# %%
#Ajusto el indice de mi DataFrame
filtro_i13 = filtro_13.set_index("accommodates")
filtro_i13
# Out:
#               frequency
# accommodates
# Categoría2        10620
# Categoría6         5690
# Categoría4         2401
# Categoría10        1800
# Categoría8         1375
# Categoría5         1352
# Categoría12         311

# %%
#Realizamos grafico de área del dataframe filtrado
filtro_i13.plot(kind='area', figsize=(10,4), alpha = 0.5)
# Out:
# <Axes: xlabel='accommodates'>

# %%
# Extraer número de baños de bathrooms_text
mexico["bathrooms_text"] = mexico["bathrooms_text"].str.extract("(\d+\.?\d*)").astype(float)
mexico['bathrooms_text'].info()
n = 8021
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 26582 entries, 0 to 26581
# Series name: bathrooms_text
# Non-Null Count  Dtype
# --------------  -----
# 26510 non-null  float64
# dtypes: float64(1)
# memory usage: 207.8 KB
# <>:2: SyntaxWarning: invalid escape sequence '\d'
# <>:2: SyntaxWarning: invalid escape sequence '\d'
# C:\Users\Bonil\AppData\Local\Temp\ipykernel_5428\2085699483.py:2: SyntaxWarning: invalid escape sequence '\d'
#   mexico["bathrooms_text"] = mexico["bathrooms_text"].str.extract("(\d+\.?\d*)").astype(float)

# %%
Min = mexico["bathrooms_text"].min()  
Max = mexico["bathrooms_text"].max()  
Limites = [Min,Max]
Limites
# Out:
# [0.0, 49.0]

# %%
R = Max - Min
R
# Out:
# 49.0

# %%
#Calcular el número de Intervalos de Clase (ni). Se aplica la regla de Sturges (Donde “n” el tamaño de la muestra.):
ni = 1+3.32*np.log10(n)
ni
# Out:
# 13.96203867424906

# %%
#Calcular el Ancho del Intervalo ( i )
i = R/ni
i
# Out:
# 3.5095161346582815

# %%
# Ver resultado
intervalos = np.linspace(0.0, 27.0, 13) #Número de clases más uno
intervalos
categorias = ["Categoría1", "Categoría2", "Categoría3", "Categoría4",
              "Categoría5", "Categoría6", "Categoría7", "Categoría8",
              "Categoría9","Categoría10","Categoría11","Categoría12"]

# %%
mexico["bathrooms_text"] = pd.cut(x = mexico["bathrooms_text"], bins = intervalos, labels = categorias)
mexico["bathrooms_text"]
# Out:
# 0        Categoría1
# 1        Categoría3
# 2        Categoría1
# 3        Categoría1
# 4        Categoría1
#             ...
# 26577    Categoría1
# 26578    Categoría1
# 26579    Categoría1
# 26580    Categoría1
# 26581    Categoría1
# Name: bathrooms_text, Length: 26582, dtype: category
# Categories (12, object): ['Categoría1' < 'Categoría2' < 'Categoría3' < 'Categoría4' ... 'Categoría9' < 'Categoría10' < 'Categoría11' < 'Categoría12']

# %%
#Obtengo un análisis univariado de una variable categórica en específico  
variable_14 = freq_tbl(mexico["bathrooms_text"])
variable_14
# Out:
#    bathrooms_text  frequency  percentage  cumulative_perc
# 0      Categoría1      23770    0.894214         0.900106
# 1      Categoría2       2285    0.085960         0.986633
# 2      Categoría3        220    0.008276         0.994964
# 3      Categoría4         80    0.003010         0.997993
# 4      Categoría6         28    0.001053         0.999053
# 5      Categoría5         15    0.000564         0.999621
# 6      Categoría7          4    0.000150         0.999773
# 7      Categoría8          4    0.000150         0.999924
# 8      Categoría9          1    0.000038         0.999962
# 9     Categoría10          1    0.000038         1.000000
# 10    Categoría11          0    0.000000         1.000000
# 11    Categoría12          0    0.000000         1.000000

# %%
#Elimino las columnas "procentage" y "cumulative_perc" para trabajar con las fecuencias
variable_14_2 = variable_14.drop(['percentage', 'cumulative_perc'], axis=1)
variable_14_2
# Out:
#    bathrooms_text  frequency
# 0      Categoría1      23770
# 1      Categoría2       2285
# 2      Categoría3        220
# 3      Categoría4         80
# 4      Categoría6         28
# 5      Categoría5         15
# 6      Categoría7          4
# 7      Categoría8          4
# 8      Categoría9          1
# 9     Categoría10          1
# 10    Categoría11          0
# 11    Categoría12          0

# %%
filtro_14 = variable_14_2[variable_14_2['frequency'] > 100]
filtro_14
# Out:
#   bathrooms_text  frequency
# 0     Categoría1      23770
# 1     Categoría2       2285
# 2     Categoría3        220

# %%
#Ajusto el indice de mi DataFrame
filtro_i14 = filtro_14.set_index("bathrooms_text")
filtro_i14
# Out:
#                 frequency
# bathrooms_text
# Categoría1          23770
# Categoría2           2285
# Categoría3            220

# %%
#Realizamos grafico de área del dataframe filtrado
filtro_i14.plot(kind='area', figsize=(10,4), alpha = 0.5)
# Out:
# <Axes: xlabel='bathrooms_text'>

# %%
mexico['beds'].info()
n = 8021
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 26582 entries, 0 to 26581
# Series name: beds
# Non-Null Count  Dtype
# --------------  -----
# 26582 non-null  float64
# dtypes: float64(1)
# memory usage: 207.8 KB

# %%
Min = mexico["beds"].min()  
Max = mexico["beds"].max()  
Limites = [Min,Max]
Limites
# Out:
# [0.0, 3.0]

# %%
#Calcula el rango
R = Max - Min
R
# Out:
# 3.0

# %%
#Calcular el número de Intervalos de Clase (ni). Se aplica la regla de Sturges (Donde “n” el tamaño de la muestra.):
ni = 1+3.32*np.log10(n)
ni
# Out:
# 13.96203867424906

# %%
#Calcular el Ancho del Intervalo ( i )
i = R/ni
i
# Out:
# 0.21486833477499684

# %%
# Ver resultado
intervalos = np.linspace(0.0, 3.0, 13) #Número de clases más uno
intervalos
# Out:
# array([0.  , 0.25, 0.5 , 0.75, 1.  , 1.25, 1.5 , 1.75, 2.  , 2.25, 2.5 ,
#        2.75, 3.  ])

# %%
categorias = ["Categoría1", "Categoría2", "Categoría3", "Categoría4",
              "Categoría5", "Categoría6", "Categoría7", "Categoría8",
              "Categoría9","Categoría10","Categoría11","Categoría12"]

# %%
mexico["beds"] = pd.cut(x = mexico["beds"], bins = intervalos, labels = categorias)
mexico["beds"]
# Out:
# 0        Categoría4
# 1        Categoría8
# 2        Categoría8
# 3        Categoría4
# 4        Categoría4
#             ...
# 26577    Categoría8
# 26578    Categoría4
# 26579    Categoría4
# 26580    Categoría4
# 26581    Categoría4
# Name: beds, Length: 26582, dtype: category
# Categories (12, object): ['Categoría1' < 'Categoría2' < 'Categoría3' < 'Categoría4' ... 'Categoría9' < 'Categoría10' < 'Categoría11' < 'Categoría12']

# %%
#Obtengo un análisis univariado de una variable categórica en específico  
variable_15 = freq_tbl(mexico["beds"])
variable_15
# Out:
#            beds  frequency  percentage  cumulative_perc
# 0    Categoría8      11867    0.446430         0.454500
# 1    Categoría4      11409    0.429200         0.891459
# 2   Categoría12       2834    0.106613         1.000000
# 3    Categoría1          0    0.000000         1.000000
# 4    Categoría2          0    0.000000         1.000000
# 5    Categoría3          0    0.000000         1.000000
# 6    Categoría5          0    0.000000         1.000000
# 7    Categoría6          0    0.000000         1.000000
# 8    Categoría7          0    0.000000         1.000000
# 9    Categoría9          0    0.000000         1.000000
# 10  Categoría10          0    0.000000         1.000000
# 11  Categoría11          0    0.000000         1.000000

# %%
#Elimino las columnas "procentage" y "cumulative_perc" para trabajar con las fecuencias
variable_15_2 = variable_15.drop(['percentage', 'cumulative_perc'], axis=1)
variable_15_2
# Out:
#            beds  frequency
# 0    Categoría8      11867
# 1    Categoría4      11409
# 2   Categoría12       2834
# 3    Categoría1          0
# 4    Categoría2          0
# 5    Categoría3          0
# 6    Categoría5          0
# 7    Categoría6          0
# 8    Categoría7          0
# 9    Categoría9          0
# 10  Categoría10          0
# 11  Categoría11          0

# %%
filtro15 = variable_15_2[variable_15_2['frequency'] > 300]
filtro15
# Out:
#           beds  frequency
# 0   Categoría8      11867
# 1   Categoría4      11409
# 2  Categoría12       2834

# %%
#Ajusto el indice de mi DataFrame
filtro_i15 = filtro15.set_index("beds")
filtro_i15
# Out:
#              frequency
# beds
# Categoría8       11867
# Categoría4       11409
# Categoría12       2834

# %%
#Realizamos grafico de barras del Dataframe filtrado
filtro_i15.plot(kind = 'bar', width=0.8, figsize=(10,4), color = "red")
plt.title('Camas')
plt.xlabel('Categoria de las camas')
plt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')

# %%
mexico["price"] = mexico["price"].replace('[\$,]', '', regex=True).astype(float)
mexico['price'].info()
n = 8021
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 26582 entries, 0 to 26581
# Series name: price
# Non-Null Count  Dtype
# --------------  -----
# 26582 non-null  float64
# dtypes: float64(1)
# memory usage: 207.8 KB
# <>:1: SyntaxWarning: invalid escape sequence '\$'
# <>:1: SyntaxWarning: invalid escape sequence '\$'
# C:\Users\Bonil\AppData\Local\Temp\ipykernel_5428\192152448.py:1: SyntaxWarning: invalid escape sequence '\$'
#   mexico["price"] = mexico["price"].replace('[\$,]', '', regex=True).astype(float)

# %%
Min = mexico["price"].min()  
Max = mexico["price"].max()  
Limites = [Min,Max]
Limites
# Out:
# [0.0, 435481.0]

# %%
#Calcula el rango
R = Max - Min
R
# Out:
# 435481.0

# %%
#Calcular el número de Intervalos de Clase (ni). Se aplica la regla de Sturges (Donde “n” el tamaño de la muestra.):
ni = 1+3.32*np.log10(n)
ni
# Out:
# 13.96203867424906

# %%
#Calcular el Ancho del Intervalo ( i )
i = R/ni
i
# Out:
# 31190.3590987168

# %%
# Ver resultado
intervalos = np.linspace(20.0, 96274.0, 13) #Número de clases más uno
intervalos
# Out:
# array([2.00000000e+01, 8.04116667e+03, 1.60623333e+04, 2.40835000e+04,
#        3.21046667e+04, 4.01258333e+04, 4.81470000e+04, 5.61681667e+04,
#        6.41893333e+04, 7.22105000e+04, 8.02316667e+04, 8.82528333e+04,
#        9.62740000e+04])

# %%
categorias = ["Categoría1", "Categoría2", "Categoría3", "Categoría4",
              "Categoría5", "Categoría6", "Categoría7", "Categoría8",
              "Categoría9","Categoría10","Categoría11","Categoría12"]

# %%
mexico["price"] = pd.cut(x = mexico["price"], bins = intervalos, labels = categorias)
mexico["price"]
# Out:
# 0        Categoría1
# 1        Categoría1
# 2        Categoría1
# 3        Categoría1
# 4        Categoría1
#             ...
# 26577    Categoría1
# 26578    Categoría1
# 26579    Categoría1
# 26580    Categoría1
# 26581    Categoría1
# Name: price, Length: 26582, dtype: category
# Categories (12, object): ['Categoría1' < 'Categoría2' < 'Categoría3' < 'Categoría4' ... 'Categoría9' < 'Categoría10' < 'Categoría11' < 'Categoría12']

# %%
#Obtengo un análisis univariado de una variable categórica en específico  
variable_16 = freq_tbl(mexico["price"])
variable_16
# Out:
#           price  frequency  percentage  cumulative_perc
# 0    Categoría1      26289    0.988978         0.989201
# 1    Categoría2        201    0.007562         0.996764
# 2    Categoría3         46    0.001730         0.998495
# 3    Categoría4         25    0.000940         0.999436
# 4    Categoría5          5    0.000188         0.999624
# 5    Categoría7          5    0.000188         0.999812
# 6    Categoría6          2    0.000075         0.999887
# 7    Categoría9          1    0.000038         0.999925
# 8   Categoría10          1    0.000038         0.999962
# 9   Categoría12          1    0.000038         1.000000
# 10   Categoría8          0    0.000000         1.000000
# 11  Categoría11          0    0.000000         1.000000

# %%
#Elimino las columnas "procentage" y "cumulative_perc" para trabajar con las fecuencias
variable_16_2 = variable_16.drop(['percentage', 'cumulative_perc'], axis=1)
variable_16_2
# Out:
#           price  frequency
# 0    Categoría1      26289
# 1    Categoría2        201
# 2    Categoría3         46
# 3    Categoría4         25
# 4    Categoría5          5
# 5    Categoría7          5
# 6    Categoría6          2
# 7    Categoría9          1
# 8   Categoría10          1
# 9   Categoría12          1
# 10   Categoría8          0
# 11  Categoría11          0

# %%
filtro16 = variable_16_2[variable_16_2['frequency'] > 0]
filtro16
# Out:
#          price  frequency
# 0   Categoría1      26289
# 1   Categoría2        201
# 2   Categoría3         46
# 3   Categoría4         25
# 4   Categoría5          5
# 5   Categoría7          5
# 6   Categoría6          2
# 7   Categoría9          1
# 8  Categoría10          1
# 9  Categoría12          1

# %%
#Ajusto el indice de mi DataFrame
filtro_i16 = filtro16.set_index("price")
filtro_i16
# Out:
#              frequency
# price
# Categoría1       26289
# Categoría2         201
# Categoría3          46
# Categoría4          25
# Categoría5           5
# Categoría7           5
# Categoría6           2
# Categoría9           1
# Categoría10          1
# Categoría12          1

# %%
#Realizamos grafico de área del dataframe filtrado
filtro_i16.plot(kind='area', figsize=(10,4), alpha = 0.5)
# Out:
# <Axes: xlabel='price'>

# %%
mexico['maximum_nights_avg_ntm'].info()
n = 8021
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 26582 entries, 0 to 26581
# Series name: maximum_nights_avg_ntm
# Non-Null Count  Dtype
# --------------  -----
# 26582 non-null  float64
# dtypes: float64(1)
# memory usage: 207.8 KB

# %%
Min = mexico["maximum_nights_avg_ntm"].min()  
Max = mexico["maximum_nights_avg_ntm"].max()  
Limites = [Min,Max]
Limites
# Out:
# [1.0, 1825.0]

# %%
#Calcula el rango
R = Max - Min
R
# Out:
# 1824.0

# %%
#Calcular el número de Intervalos de Clase (ni). Se aplica la regla de Sturges (Donde “n” el tamaño de la muestra.):
ni = 1+3.32*np.log10(n)
ni
# Out:
# 13.96203867424906

# %%
#Calcular el Ancho del Intervalo ( i )
i = R/ni
i
# Out:
# 130.63994754319808

# %%
# Ver resultado
intervalos = np.linspace(1.0, 20770.8, 13) #Número de clases más uno
intervalos
categorias = ["Categoría1", "Categoría2", "Categoría3", "Categoría4",
              "Categoría5", "Categoría6", "Categoría7", "Categoría8",
              "Categoría9","Categoría10","Categoría11","Categoría12"]

# %%
mexico["maximum_nights_avg_ntm"] = pd.cut(x = mexico["maximum_nights_avg_ntm"], bins = intervalos, labels = categorias)
mexico["maximum_nights_avg_ntm"]
# Out:
# 0        Categoría1
# 1        Categoría1
# 2        Categoría1
# 3        Categoría1
# 4        Categoría1
#             ...
# 26577    Categoría1
# 26578    Categoría1
# 26579    Categoría1
# 26580    Categoría1
# 26581    Categoría1
# Name: maximum_nights_avg_ntm, Length: 26582, dtype: category
# Categories (12, object): ['Categoría1' < 'Categoría2' < 'Categoría3' < 'Categoría4' ... 'Categoría9' < 'Categoría10' < 'Categoría11' < 'Categoría12']

# %%
#Obtengo un análisis univariado de una variable categórica en específico  
variable_17 = freq_tbl(mexico["maximum_nights_avg_ntm"])
variable_17
# Out:
#    maximum_nights_avg_ntm  frequency  percentage  cumulative_perc
# 0              Categoría1      26568    0.999473         0.999962
# 1              Categoría2          1    0.000038         1.000000
# 2              Categoría3          0    0.000000         1.000000
# 3              Categoría4          0    0.000000         1.000000
# 4              Categoría5          0    0.000000         1.000000
# 5              Categoría6          0    0.000000         1.000000
# 6              Categoría7          0    0.000000         1.000000
# 7              Categoría8          0    0.000000         1.000000
# 8              Categoría9          0    0.000000         1.000000
# 9             Categoría10          0    0.000000         1.000000
# 10            Categoría11          0    0.000000         1.000000
# 11            Categoría12          0    0.000000         1.000000

# %%
#Elimino las columnas "procentage" y "cumulative_perc" para trabajar con las fecuencias
variable_17_2 = variable_17.drop(['percentage', 'cumulative_perc'], axis=1)
variable_17_2
# Out:
#    maximum_nights_avg_ntm  frequency
# 0              Categoría1      26568
# 1              Categoría2          1
# 2              Categoría3          0
# 3              Categoría4          0
# 4              Categoría5          0
# 5              Categoría6          0
# 6              Categoría7          0
# 7              Categoría8          0
# 8              Categoría9          0
# 9             Categoría10          0
# 10            Categoría11          0
# 11            Categoría12          0

# %%
filtro_17 = variable_17_2[variable_17_2['frequency'] > 0]
filtro_17
# Out:
#   maximum_nights_avg_ntm  frequency
# 0             Categoría1      26568
# 1             Categoría2          1

# %%
#Ajusto el indice de mi DataFrame
filtro_i17 = filtro_17.set_index("maximum_nights_avg_ntm")
filtro_i17
# Out:
#                         frequency
# maximum_nights_avg_ntm
# Categoría1                  26568
# Categoría2                      1

# %%
#Realizamos grafico de barras del Dataframe filtrado
filtro_i17.plot(kind = 'bar', width=0.8, figsize=(10,4), color = "red")
plt.title('maximum_nights_avg_ntm')
plt.xlabel('Maxima noche')
plt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')
